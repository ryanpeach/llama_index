# %% [markdown]
# # Code Hierarchy Node Parser
#
# The `CodeHierarchyNodeParser` is useful to split long code files into more reasonable chunks. What this will do is create a "Hierarchy" of sorts, where sections of the code are made more reasonable by replacing the scope body with short comments telling the LLM to search for a referenced node if it wants to read that context body. This is called skeletonization, and is toggled by setting `skeleton` to `True` which it is by default. Nodes in this hierarchy will be split based on scope, like function, class, or method scope, and will have links to their children and parents so the LLM can traverse the tree.

# %% [markdown]
# ## Installation and Import
#
# First be sure to install the necessary [tree-sitter](https://tree-sitter.github.io/tree-sitter/) libraries.
#
# `pip install tree-sitter tree-sitter-languages`

# %%
from llama_index.node_parser.code_hierarchy import CodeHierarchyNodeParser
from llama_index.text_splitter.code_splitter import CodeSplitter
from llama_index.readers import SimpleDirectoryReader
from pathlib import Path
from pprint import pprint

# %% [markdown]
# Now, choose a directory you want to scan, and glob for all the code files you want to import.
#
# In this case I'm going to glob all "*.py" files in the `llama_index/node_parser` directory.

# %%
reader = SimpleDirectoryReader(
    input_files=Path("../../../../llama_index/node_parser").glob("*.py"),
    file_metadata=lambda x: {"filepath": x},
)
nodes = reader.load_data()
len(nodes)
# Out:
# 10

# %% [markdown]
# Looks like we got 8 files. Lets examine one of these nodes.
# We see here that the second one is 28756 characters long. That's way too long for most LLMs.

# %%
print(len(nodes[1].text))
pprint(nodes[1].text)
# Out:
# 29996
# ('from enum import Enum\n'
#  'from typing import Dict, List, Optional, Sequence, Tuple\n'
#  '\n'
#  'from llama_index.node_parser.extractors.metadata_extractors import '
#  'MetadataExtractor\n'
#  'from llama_index.node_parser.interface import NodeParser\n'
#  'from llama_index.node_parser.node_utils import get_nodes_from_node\n'
#  '\n'
#  'try:\n'
#  '    from pydantic.v1 import BaseModel, Field\n'
#  'except ImportError:\n'
#  '    from pydantic import BaseModel, Field\n'
#  '\n'
#  '\n'
#  'from tree_sitter import Node\n'
#  '\n'
#  'from llama_index.callbacks.base import CallbackManager\n'
#  'from llama_index.callbacks.schema import CBEventType, EventPayload\n'
#  'from llama_index.schema import BaseNode, Document, NodeRelationship, '
#  'TextNode\n'
#  'from llama_index.text_splitter.code_splitter import CodeSplitter\n'
#  'from llama_index.utils import get_tqdm_iterable\n'
#  '\n'
#  '\n'
#  'class _SignatureCaptureType(BaseModel):\n'
#  '    """\n'
#  '    Unfortunately some languages need special options for how to make a '
#  'signature.\n'
#  '\n'
#  '    For example, html element signatures should include their closing >, '
#  'there is no\n'
#  '    easy way to include this using an always-exclusive system.\n'
#  '\n'
#  "    However, using an always-inclusive system, python decorators don't "
#  'work,\n'
#  "    as there isn't an easy to define terminator for decorators that is "
#  'inclusive\n'
#  '    to their signature.\n'
#  '    """\n'
#  '\n'
#  '    type: str = Field(description="The type string to match on.")\n'
#  '    inclusive: bool = Field(\n'
#  '        description=(\n'
#  '            "Whether to include the text of the node matched by this type or '
#  'not."\n'
#  '        ),\n'
#  '    )\n'
#  '\n'
#  '\n'
#  'class _SignatureCaptureOptions(BaseModel):\n'
#  '    start_signature_types: Optional[List[_SignatureCaptureType]] = Field(\n'
#  '        None,\n'
#  '        description=(\n'
#  '            "A list of node types any of which indicate the beginning of the '
#  'signature."\n'
#  '            "If this is none or empty, use the start_byte of the node."\n'
#  '        ),\n'
#  '    )\n'
#  '    end_signature_types: Optional[List[_SignatureCaptureType]] = Field(\n'
#  '        None,\n'
#  '        description=(\n'
#  '            "A list of node types any of which indicate the end of the '
#  'signature."\n'
#  '            "If this is none or empty, use the end_byte of the node."\n'
#  '        ),\n'
#  '    )\n'
#  '    name_identifier: str = Field(\n'
#  '        description=(\n'
#  '            "The node type to use for the signatures \'name\'.If retrieving '
#  'the name is"\n'
#  '            " more complicated than a simple type match, use a function '
#  'which takes a"\n'
#  '            " node and returns true or false as to whether its the name or '
#  'not. The"\n'
#  '            " first match is returned."\n'
#  '        )\n'
#  '    )\n'
#  '\n'
#  '\n'
#  '"""\n'
#  'Maps language -> Node Type -> SignatureCaptureOptions\n'
#  '\n'
#  'The best way for a developer to discover these is to put a breakpoint at the '
#  'TIP\n'
#  'tag in _chunk_node, and then create a unit test for some code, and then '
#  'iterate\n'
#  'through the code discovering the node names.\n'
#  '"""\n'
#  '_DEFAULT_SIGNATURE_IDENTIFIERS: Dict[str, Dict[str, '
#  '_SignatureCaptureOptions]] = {\n'
#  '    "python": {\n'
#  '        "function_definition": _SignatureCaptureOptions(\n'
#  '            end_signature_types=[_SignatureCaptureType(type="block", '
#  'inclusive=False)],\n'
#  '            name_identifier="identifier",\n'
#  '        ),\n'
#  '        "class_definition": _SignatureCaptureOptions(\n'
#  '            end_signature_types=[_SignatureCaptureType(type="block", '
#  'inclusive=False)],\n'
#  '            name_identifier="identifier",\n'
#  '        ),\n'
#  '    },\n'
#  '    "html": {\n'
#  '        "element": _SignatureCaptureOptions(\n'
#  '            start_signature_types=[_SignatureCaptureType(type="<", '
#  'inclusive=True)],\n'
#  '            end_signature_types=[_SignatureCaptureType(type=">", '
#  'inclusive=True)],\n'
#  '            name_identifier="tag_name",\n'
#  '        )\n'
#  '    },\n'
#  '    "cpp": {\n'
#  '        "class_specifier": _SignatureCaptureOptions(\n'
#  '            end_signature_types=[_SignatureCaptureType(type="{", '
#  'inclusive=False)],\n'
#  '            name_identifier="type_identifier",\n'
#  '        ),\n'
#  '        "function_definition": _SignatureCaptureOptions(\n'
#  '            end_signature_types=[_SignatureCaptureType(type="{", '
#  'inclusive=False)],\n'
#  '            name_identifier="function_declarator",\n'
#  '        ),\n'
#  '    },\n'
#  '    "typescript": {\n'
#  '        "interface_declaration": _SignatureCaptureOptions(\n'
#  '            end_signature_types=[_SignatureCaptureType(type="{", '
#  'inclusive=False)],\n'
#  '            name_identifier="type_identifier",\n'
#  '        ),\n'
#  '        "lexical_declaration": _SignatureCaptureOptions(\n'
#  '            end_signature_types=[_SignatureCaptureType(type="{", '
#  'inclusive=False)],\n'
#  '            name_identifier="identifier",\n'
#  '        ),\n'
#  '        "function_declaration": _SignatureCaptureOptions(\n'
#  '            end_signature_types=[_SignatureCaptureType(type="{", '
#  'inclusive=False)],\n'
#  '            name_identifier="identifier",\n'
#  '        ),\n'
#  '        "class_declaration": _SignatureCaptureOptions(\n'
#  '            end_signature_types=[_SignatureCaptureType(type="{", '
#  'inclusive=False)],\n'
#  '            name_identifier="type_identifier",\n'
#  '        ),\n'
#  '        "method_definition": _SignatureCaptureOptions(\n'
#  '            end_signature_types=[_SignatureCaptureType(type="{", '
#  'inclusive=False)],\n'
#  '            name_identifier="property_identifier",\n'
#  '        ),\n'
#  '    },\n'
#  '}\n'
#  '\n'
#  '\n'
#  'class _ScopeMethod(Enum):\n'
#  '    INDENTATION = "INDENTATION"\n'
#  '    BRACKETS = "BRACKETS"\n'
#  '    HTML_END_TAGS = "HTML_END_TAGS"\n'
#  '\n'
#  '\n'
#  'class _CommentOptions(BaseModel):\n'
#  '    comment_template: str\n'
#  '    scope_method: _ScopeMethod\n'
#  '\n'
#  '\n'
#  '_COMMENT_OPTIONS: Dict[str, _CommentOptions] = {\n'
#  '    "cpp": _CommentOptions(\n'
#  '        comment_template="// {}", scope_method=_ScopeMethod.BRACKETS\n'
#  '    ),\n'
#  '    "html": _CommentOptions(\n'
#  '        comment_template="<!-- {} -->", '
#  'scope_method=_ScopeMethod.HTML_END_TAGS\n'
#  '    ),\n'
#  '    "python": _CommentOptions(\n'
#  '        comment_template="# {}", scope_method=_ScopeMethod.INDENTATION\n'
#  '    ),\n'
#  '    "typescript": _CommentOptions(\n'
#  '        comment_template="// {}", scope_method=_ScopeMethod.BRACKETS\n'
#  '    ),\n'
#  '}\n'
#  '\n'
#  'assert all(\n'
#  '    language in _DEFAULT_SIGNATURE_IDENTIFIERS for language in '
#  '_COMMENT_OPTIONS\n'
#  '), "Not all languages in _COMMENT_OPTIONS are in '
#  '_DEFAULT_SIGNATURE_IDENTIFIERS"\n'
#  'assert all(\n'
#  '    language in _COMMENT_OPTIONS for language in '
#  '_DEFAULT_SIGNATURE_IDENTIFIERS\n'
#  '), "Not all languages in _DEFAULT_SIGNATURE_IDENTIFIERS are in '
#  '_COMMENT_OPTIONS"\n'
#  '\n'
#  '\n'
#  'class _ScopeItem(BaseModel):\n'
#  '    """Like a Node from tree_sitter, but with only the str information we '
#  'need."""\n'
#  '\n'
#  '    name: str\n'
#  '    type: str\n'
#  '    signature: str\n'
#  '\n'
#  '\n'
#  'class _ChunkNodeOutput(BaseModel):\n'
#  '    """The output of a chunk_node call."""\n'
#  '\n'
#  '    this_document: Optional[TextNode]\n'
#  '    upstream_children_documents: List[TextNode]\n'
#  '    all_documents: List[TextNode]\n'
#  '\n'
#  '\n'
#  'class CodeHierarchyNodeParser(NodeParser):\n'
#  '    """Split code using a AST parser.\n'
#  '\n'
#  '    Add metadata about the scope of the code block and relationships '
#  'between\n'
#  '    code blocks.\n'
#  '    """\n'
#  '\n'
#  '    @classmethod\n'
#  '    def class_name(cls) -> str:\n'
#  '        """Get class name."""\n'
#  '        return "CodeHierarchyNodeParser"\n'
#  '\n'
#  '    language: str = Field(\n'
#  '        description="The programming language of the code being split."\n'
#  '    )\n'
#  '    signature_identifiers: Dict[str, _SignatureCaptureOptions] = Field(\n'
#  '        description=(\n'
#  '            "A dictionary mapping the type of a split mapped to the first '
#  'and last type"\n'
#  '            " of itschildren which identify its signature."\n'
#  '        )\n'
#  '    )\n'
#  '    min_characters: int = Field(\n'
#  '        default=80,\n'
#  '        description=(\n'
#  '            "Minimum number of characters per chunk.Defaults to 80 because '
#  'that\'s about"\n'
#  '            " how long a replacement comment is in skeleton mode."\n'
#  '        ),\n'
#  '    )\n'
#  '    code_splitter: Optional[CodeSplitter] = Field(\n'
#  '        description="The text splitter to use when splitting documents."\n'
#  '    )\n'
#  '    metadata_extractor: Optional[MetadataExtractor] = Field(\n'
#  '        default=None, description="Metadata extraction pipeline to apply to '
#  'nodes."\n'
#  '    )\n'
#  '    callback_manager: CallbackManager = Field(\n'
#  '        default_factory=CallbackManager, exclude=True\n'
#  '    )\n'
#  '    skeleton: bool = Field(\n'
#  '        True,\n'
#  '        description=(\n'
#  '            "Parent nodes have the text of their child nodes replaced with a '
#  'signature"\n'
#  '            " and a comment instructing the language model to visit the '
#  'child node for"\n'
#  '            " the full text of the scope."\n'
#  '        ),\n'
#  '    )\n'
#  '\n'
#  '    def __init__(\n'
#  '        self,\n'
#  '        language: str,\n'
#  '        skeleton: bool = True,\n'
#  '        signature_identifiers: Optional[Dict[str, _SignatureCaptureOptions]] '
#  '= None,\n'
#  '        code_splitter: Optional[CodeSplitter] = None,\n'
#  '        callback_manager: Optional[CallbackManager] = None,\n'
#  '        metadata_extractor: Optional[MetadataExtractor] = None,\n'
#  '        min_characters: int = 80,\n'
#  '    ):\n'
#  '        callback_manager = callback_manager or CallbackManager([])\n'
#  '\n'
#  '        if signature_identifiers is None:\n'
#  '            try:\n'
#  '                signature_identifiers = '
#  '_DEFAULT_SIGNATURE_IDENTIFIERS[language]\n'
#  '            except KeyError:\n'
#  '                raise ValueError(\n'
#  '                    f"Must provide signature_identifiers for language '
#  '{language}."\n'
#  '                )\n'
#  '\n'
#  '        super().__init__(\n'
#  '            language=language,\n'
#  '            callback_manager=callback_manager,\n'
#  '            metadata_extractor=metadata_extractor,\n'
#  '            code_splitter=code_splitter,\n'
#  '            signature_identifiers=signature_identifiers,\n'
#  '            min_characters=min_characters,\n'
#  '            skeleton=skeleton,\n'
#  '        )\n'
#  '\n'
#  '    def _get_node_name(self, node: Node) -> str:\n'
#  '        """Get the name of a node."""\n'
#  '        signature_identifier = self.signature_identifiers[node.type]\n'
#  '\n'
#  '        def recur(node: Node) -> str:\n'
#  '            for child in node.children:\n'
#  '                if child.type == signature_identifier.name_identifier:\n'
#  '                    return child.text.decode()\n'
#  '                if child.children:\n'
#  '                    out = recur(child)\n'
#  '                    if out:\n'
#  '                        return out\n'
#  '            return ""\n'
#  '\n'
#  '        return recur(node).strip()\n'
#  '\n'
#  '    def _get_node_signature(self, text: str, node: Node) -> str:\n'
#  '        """Get the signature of a node."""\n'
#  '        signature_identifier = self.signature_identifiers[node.type]\n'
#  '\n'
#  '        def find_start(node: Node) -> Optional[int]:\n'
#  '            if not signature_identifier.start_signature_types:\n'
#  '                signature_identifier.start_signature_types = []\n'
#  '\n'
#  '            for st in signature_identifier.start_signature_types:\n'
#  '                if node.type == st.type:\n'
#  '                    if st.inclusive:\n'
#  '                        return node.start_byte\n'
#  '                    return node.end_byte\n'
#  '\n'
#  '            for child in node.children:\n'
#  '                out = find_start(child)\n'
#  '                if out is not None:\n'
#  '                    return out\n'
#  '\n'
#  '            return None\n'
#  '\n'
#  '        def find_end(node: Node) -> Optional[int]:\n'
#  '            if not signature_identifier.end_signature_types:\n'
#  '                signature_identifier.end_signature_types = []\n'
#  '\n'
#  '            for st in signature_identifier.end_signature_types:\n'
#  '                if node.type == st.type:\n'
#  '                    if st.inclusive:\n'
#  '                        return node.end_byte\n'
#  '                    return node.start_byte\n'
#  '\n'
#  '            for child in node.children:\n'
#  '                out = find_end(child)\n'
#  '                if out is not None:\n'
#  '                    return out\n'
#  '\n'
#  '            return None\n'
#  '\n'
#  '        start_byte, end_byte = find_start(node), find_end(node)\n'
#  '        if start_byte is None:\n'
#  '            start_byte = node.start_byte\n'
#  '        if end_byte is None:\n'
#  '            end_byte = node.end_byte\n'
#  '        return text[start_byte:end_byte].strip()\n'
#  '\n'
#  '    def _chunk_node(\n'
#  '        self,\n'
#  '        parent: Node,\n'
#  '        text: str,\n'
#  '        _context_list: Optional[List[_ScopeItem]] = None,\n'
#  '        _root: bool = True,\n'
#  '    ) -> _ChunkNodeOutput:\n'
#  '        """\n'
#  '        This is really the "main" method of this class. It is recursive and '
#  'recursively\n'
#  '        chunks the text by the options identified in '
#  'self.signature_identifiers.\n'
#  '\n'
#  '        It is ran by get_nodes_from_documents.\n'
#  '\n'
#  '        Args:\n'
#  '            parent (Node): The parent node to chunk\n'
#  '            text (str): The text of the entire document\n'
#  '            _context_list (Optional[List[_ScopeItem]]): The scope context of '
#  'the\n'
#  '                                                        parent node\n'
#  '            _root (bool): Whether or not this is the root node\n'
#  '        """\n'
#  '        if _context_list is None:\n'
#  '            _context_list = []\n'
#  '\n'
#  '        upstream_children_documents: List[TextNode] = []\n'
#  '        all_documents: List[TextNode] = []\n'
#  '\n'
#  '        # Capture any whitespace before parent.start_byte\n'
#  '        # Very important for space sensitive languages like python\n'
#  '        start_byte = parent.start_byte\n'
#  '        while start_byte > 0 and text[start_byte - 1] in (" ", "\\t"):\n'
#  '            start_byte -= 1\n'
#  '\n'
#  '        # Create this node\n'
#  '        current_chunk = text[start_byte : parent.end_byte]\n'
#  '\n'
#  '        # Return early if the chunk is too small\n'
#  '        if len(current_chunk) < self.min_characters and not _root:\n'
#  '            return _ChunkNodeOutput(\n'
#  '                this_document=None, all_documents=[], '
#  'upstream_children_documents=[]\n'
#  '            )\n'
#  '\n'
#  '        # TIP: This is a wonderful place to put a debug breakpoint when\n'
#  '        #      Trying to integrate a new language. Pay attention to '
#  'parent.type to learn\n'
#  '        #      all the available node types and their hierarchy.\n'
#  '        if parent.type in self.signature_identifiers or _root:\n'
#  '            # Get the new context\n'
#  '            if not _root:\n'
#  '                new_context = _ScopeItem(\n'
#  '                    name=self._get_node_name(parent),\n'
#  '                    type=parent.type,\n'
#  '                    signature=self._get_node_signature(text=text, '
#  'node=parent),\n'
#  '                )\n'
#  '                _context_list.append(new_context)\n'
#  '            this_document = TextNode(\n'
#  '                text=current_chunk,\n'
#  '                metadata={\n'
#  '                    "inclusive_scopes": [cl.dict() for cl in '
#  '_context_list],\n'
#  '                },\n'
#  '                relationships={\n'
#  '                    NodeRelationship.CHILD: [],\n'
#  '                },\n'
#  '            )\n'
#  '            all_documents.append(this_document)\n'
#  '        else:\n'
#  '            this_document = None\n'
#  '\n'
#  '        # Iterate over children\n'
#  '        for child in parent.children:\n'
#  '            if child.children:\n'
#  '                # Recurse on the child\n'
#  '                next_chunks = self._chunk_node(\n'
#  '                    child, text, _context_list=_context_list.copy(), '
#  '_root=False\n'
#  '                )\n'
#  '\n'
#  '                # If there is a this_document, then we need\n'
#  '                # to add the children to this_document\n'
#  '                # and flush upstream_children_documents\n'
#  '                if this_document is not None:\n'
#  "                    # If we have been given a document, that means it's "
#  'children\n'
#  '                    # are already set, so it needs to become a child of this '
#  'node\n'
#  '                    if next_chunks.this_document is not None:\n'
#  '                        assert not next_chunks.upstream_children_documents, '
#  '(\n'
#  '                            "next_chunks.this_document and"\n'
#  '                            " next_chunks.upstream_children_documents are '
#  'exclusive."\n'
#  '                        )\n'
#  '                        this_document.relationships[\n'
#  '                            NodeRelationship.CHILD\n'
#  '                        ].append(  # type: ignore\n'
#  '                            '
#  'next_chunks.this_document.as_related_node_info()\n'
#  '                        )\n'
#  '                        next_chunks.this_document.relationships[\n'
#  '                            NodeRelationship.PARENT\n'
#  '                        ] = this_document.as_related_node_info()\n'
#  '                    # Otherwise, we have been given a list of\n'
#  '                    # upstream_children_documents. We need to make\n'
#  '                    # them a child of this node\n'
#  '                    else:\n'
#  '                        for d in next_chunks.upstream_children_documents:\n'
#  '                            this_document.relationships[\n'
#  '                                NodeRelationship.CHILD\n'
#  '                            ].append(  # type: ignore\n'
#  '                                d.as_related_node_info()\n'
#  '                            )\n'
#  '                            d.relationships[\n'
#  '                                NodeRelationship.PARENT\n'
#  '                            ] = this_document.as_related_node_info()\n'
#  '                # Otherwise we pass the children upstream\n'
#  '                else:\n'
#  "                    # If we have been given a document, that means it's\n"
#  '                    # children are already set, so it needs to become a\n'
#  '                    # child of the next node\n'
#  '                    if next_chunks.this_document is not None:\n'
#  '                        assert not next_chunks.upstream_children_documents, '
#  '(\n'
#  '                            "next_chunks.this_document and"\n'
#  '                            " next_chunks.upstream_children_documents are '
#  'exclusive."\n'
#  '                        )\n'
#  '                        '
#  'upstream_children_documents.append(next_chunks.this_document)\n'
#  '                    # Otherwise, we have leftover children, they need\n'
#  '                    # to become children of the next node\n'
#  '                    else:\n'
#  '                        upstream_children_documents.extend(\n'
#  '                            next_chunks.upstream_children_documents\n'
#  '                        )\n'
#  '\n'
#  '                # Lastly we need to maintain all documents\n'
#  '                all_documents.extend(next_chunks.all_documents)\n'
#  '\n'
#  '        return _ChunkNodeOutput(\n'
#  '            this_document=this_document,\n'
#  '            upstream_children_documents=upstream_children_documents,\n'
#  '            all_documents=all_documents,\n'
#  '        )\n'
#  '\n'
#  '    def get_nodes_from_documents(\n'
#  '        self,\n'
#  '        documents: Sequence[Document],\n'
#  '        show_progress: bool = False,\n'
#  '    ) -> List[BaseNode]:\n'
#  '        """\n'
#  '        The main public method of this class.\n'
#  '\n'
#  '        Parse documents into nodes.\n'
#  '        """\n'
#  '        out: List[BaseNode] = []\n'
#  '        with self.callback_manager.event(\n'
#  '            CBEventType.CHUNKING,\n'
#  '            payload={EventPayload.CHUNKS: [document.text for document in '
#  'documents]},\n'
#  '        ) as event:\n'
#  '            try:\n'
#  '                import tree_sitter_languages\n'
#  '            except ImportError:\n'
#  '                raise ImportError(\n'
#  '                    "Please install tree_sitter_languages to use '
#  'CodeSplitter."\n'
#  '                )\n'
#  '\n'
#  '            try:\n'
#  '                parser = tree_sitter_languages.get_parser(self.language)\n'
#  '            except Exception as e:\n'
#  '                print(\n'
#  '                    f"Could not get parser for language {self.language}. '
#  'Check "\n'
#  '                    '
#  '"https://github.com/grantjenks/py-tree-sitter-languages#license "\n'
#  '                    "for a list of valid languages."\n'
#  '                )\n'
#  '                raise e  # noqa: TRY201\n'
#  '\n'
#  '            documents_with_progress = get_tqdm_iterable(\n'
#  '                documents, show_progress, "Parsing documents into nodes"\n'
#  '            )\n'
#  '            for document in documents_with_progress:\n'
#  '                text = document.text\n'
#  '                tree = parser.parse(bytes(text, "utf-8"))\n'
#  '\n'
#  '                if (\n'
#  '                    not tree.root_node.children\n'
#  '                    or tree.root_node.children[0].type != "ERROR"\n'
#  '                ):\n'
#  '                    # Chunk the code\n'
#  '                    _chunks = self._chunk_node(tree.root_node, '
#  'document.text)\n'
#  '                    assert (\n'
#  '                        _chunks.this_document is not None\n'
#  '                    ), "Root node must be a chunk"\n'
#  '                    chunks = _chunks.all_documents\n'
#  '\n'
#  '                    # Add your metadata to the chunks here\n'
#  '                    for chunk in chunks:\n'
#  '                        chunk.metadata = {\n'
#  '                            "language": self.language,\n'
#  '                            **chunk.metadata,\n'
#  '                            **document.metadata,\n'
#  '                        }\n'
#  '                        chunk.relationships[\n'
#  '                            NodeRelationship.SOURCE\n'
#  '                        ] = document.as_related_node_info()\n'
#  '\n'
#  '                    if self.skeleton:\n'
#  '                        self._skeletonize_list(chunks)\n'
#  '\n'
#  '                    # Now further split the code by lines and characters\n'
#  '                    # TODO: Test this and the relationships it creates\n'
#  '                    if self.code_splitter:\n'
#  '                        new_nodes = []\n'
#  '                        for original_node in chunks:\n'
#  '                            new_split_nodes = get_nodes_from_node(\n'
#  '                                original_node,\n'
#  '                                text_splitter=self.code_splitter,\n'
#  '                                include_metadata=True,\n'
#  '                                include_prev_next_rel=True,\n'
#  '                            )\n'
#  '\n'
#  '                            # Force the first new_split_node to have the\n'
#  '                            # same id as the original_node\n'
#  '                            new_split_nodes[0].id_ = original_node.id_\n'
#  '\n'
#  '                            # Add the parent child info to all the '
#  'new_nodes_\n'
#  '                            # derived from node\n'
#  '                            for new_split_node in new_split_nodes:\n'
#  '                                new_split_node.relationships[\n'
#  '                                    NodeRelationship.CHILD\n'
#  '                                ] = original_node.child_nodes  # type: '
#  'ignore\n'
#  '                                new_split_node.relationships[\n'
#  '                                    NodeRelationship.PARENT\n'
#  '                                ] = original_node.parent_node  # type: '
#  'ignore\n'
#  '\n'
#  '                            # Go through chunks and replace all\n'
#  '                            # instances of node.node_id in relationships\n'
#  '                            # with new_nodes_[0].node_id\n'
#  '                            for old_node in chunks:\n'
#  '                                # Handle child nodes, which are a list\n'
#  '                                new_children = []\n'
#  '                                for old_nodes_child in old_node.child_nodes '
#  'or []:\n'
#  '                                    if old_nodes_child.node_id == '
#  'original_node.node_id:\n'
#  '                                        new_children.append(\n'
#  '                                            '
#  'new_split_nodes[0].as_related_node_info()\n'
#  '                                        )\n'
#  '                                    new_children.append(old_nodes_child)\n'
#  '                                old_node.relationships[\n'
#  '                                    NodeRelationship.CHILD\n'
#  '                                ] = new_children\n'
#  '\n'
#  '                                # Handle parent node\n'
#  '                                if (\n'
#  '                                    old_node.parent_node\n'
#  '                                    and old_node.parent_node.node_id\n'
#  '                                    == original_node.node_id\n'
#  '                                ):\n'
#  '                                    old_node.relationships[\n'
#  '                                        NodeRelationship.PARENT\n'
#  '                                    ] = '
#  'new_split_nodes[0].as_related_node_info()\n'
#  '\n'
#  '                            # Now save new_nodes_\n'
#  '                            new_nodes += new_split_nodes\n'
#  '\n'
#  '                        chunks = new_nodes\n'
#  '\n'
#  '                    # Or just extract metadata\n'
#  '                    if self.metadata_extractor:\n'
#  '                        chunks = self.metadata_extractor.process_nodes(  # '
#  'type: ignore\n'
#  '                            chunks\n'
#  '                        )\n'
#  '\n'
#  '                    event.on_end(\n'
#  '                        payload={EventPayload.CHUNKS: chunks},\n'
#  '                    )\n'
#  '\n'
#  '                    out += chunks\n'
#  '                else:\n'
#  '                    raise ValueError(\n'
#  '                        f"Could not parse code with language '
#  '{self.language}."\n'
#  '                    )\n'
#  '\n'
#  '        return out\n'
#  '\n'
#  '    @staticmethod\n'
#  '    def _get_indentation(text: str) -> Tuple[str, int, int]:\n'
#  '        indent_char = None\n'
#  '        minimum_chain = None\n'
#  '\n'
#  '        # Check that text is at least 1 line long\n'
#  '        text_split = text.splitlines()\n'
#  '        if len(text_split) == 0:\n'
#  '            raise ValueError("Text should be at least one line long.")\n'
#  '\n'
#  '        for line in text_split:\n'
#  '            stripped_line = line.lstrip()\n'
#  '\n'
#  '            if stripped_line:\n'
#  "                # Get whether it's tabs or spaces\n"
#  '                spaces_count = line.count(" ", 0, len(line) - '
#  'len(stripped_line))\n'
#  '                tabs_count = line.count("\\t", 0, len(line) - '
#  'len(stripped_line))\n'
#  '\n'
#  '                if not indent_char:\n'
#  '                    if spaces_count:\n'
#  '                        indent_char = " "\n'
#  '                    if tabs_count:\n'
#  '                        indent_char = "\\t"\n'
#  '\n'
#  '                # Detect mixed indentation.\n'
#  '                if spaces_count > 0 and tabs_count > 0:\n'
#  '                    raise ValueError("Mixed indentation found.")\n'
#  '                if indent_char == " " and tabs_count > 0:\n'
#  '                    raise ValueError("Mixed indentation found.")\n'
#  '                if indent_char == "\\t" and spaces_count > 0:\n'
#  '                    raise ValueError("Mixed indentation found.")\n'
#  '\n'
#  '                # Get the minimum chain of indent_char\n'
#  '                if indent_char:\n'
#  '                    char_count = line.count(\n'
#  '                        indent_char, 0, len(line) - len(stripped_line)\n'
#  '                    )\n'
#  '                    if minimum_chain is not None:\n'
#  '                        if char_count > 0:\n'
#  '                            minimum_chain = min(char_count, minimum_chain)\n'
#  '                    else:\n'
#  '                        if char_count > 0:\n'
#  '                            minimum_chain = char_count\n'
#  '\n'
#  '        # Handle edge case\n'
#  '        if indent_char is None:\n'
#  '            indent_char = " "\n'
#  '        if minimum_chain is None:\n'
#  '            minimum_chain = 4\n'
#  '\n'
#  '        # Get the first indent count\n'
#  '        first_line = text_split[0]\n'
#  '        first_indent_count = 0\n'
#  '        for char in first_line:\n'
#  '            if char == indent_char:\n'
#  '                first_indent_count += 1\n'
#  '            else:\n'
#  '                break\n'
#  '\n'
#  '        # Return the default indent level if only one indentation level was '
#  'found.\n'
#  '        return indent_char, minimum_chain, first_indent_count // '
#  'minimum_chain\n'
#  '\n'
#  '    @staticmethod\n'
#  '    def _get_comment_text(node: TextNode) -> str:\n'
#  '        """Gets just the natural language text for a skeletonize '
#  'comment."""\n'
#  '        return f"Code replaced for brevity. See node_id {node.node_id}"\n'
#  '\n'
#  '    @classmethod\n'
#  '    def _get_replacement_text(cls, child_node: TextNode) -> str:\n'
#  '        """\n'
#  '        Manufactures a the replacement text to use to skeletonize a given '
#  'child node.\n'
#  '        """\n'
#  '        signature = '
#  'child_node.metadata["inclusive_scopes"][-1]["signature"]\n'
#  '        language = child_node.metadata["language"]\n'
#  '        if language not in _COMMENT_OPTIONS:\n'
#  '            # TODO: Create a contribution message\n'
#  '            raise KeyError("Language not yet supported. Please '
#  'contribute!")\n'
#  '        comment_options = _COMMENT_OPTIONS[language]\n'
#  '\n'
#  '        # Create the text to replace the child_node.text with\n'
#  '        (\n'
#  '            indentation_char,\n'
#  '            indentation_count_per_lvl,\n'
#  '            first_indentation_lvl,\n'
#  '        ) = cls._get_indentation(child_node.text)\n'
#  '\n'
#  '        # Start with a properly indented signature\n'
#  '        replacement_txt = (\n'
#  '            indentation_char * indentation_count_per_lvl * '
#  'first_indentation_lvl\n'
#  '            + signature\n'
#  '        )\n'
#  '\n'
#  '        # Add brackets if necessary. Expandable in the\n'
#  '        # future to other methods of scoping.\n'
#  '        if comment_options.scope_method == _ScopeMethod.BRACKETS:\n'
#  '            replacement_txt += " {\\n"\n'
#  '            replacement_txt += (\n'
#  '                indentation_char\n'
#  '                * indentation_count_per_lvl\n'
#  '                * (first_indentation_lvl + 1)\n'
#  '                + comment_options.comment_template.format(\n'
#  '                    cls._get_comment_text(child_node)\n'
#  '                )\n'
#  '                + "\\n"\n'
#  '            )\n'
#  '            replacement_txt += (\n'
#  '                indentation_char * indentation_count_per_lvl * '
#  'first_indentation_lvl\n'
#  '                + "}"\n'
#  '            )\n'
#  '\n'
#  '        elif comment_options.scope_method == _ScopeMethod.INDENTATION:\n'
#  '            replacement_txt += "\\n"\n'
#  '            replacement_txt += indentation_char * indentation_count_per_lvl '
#  '* (\n'
#  '                first_indentation_lvl + 1\n'
#  '            ) + comment_options.comment_template.format(\n'
#  '                cls._get_comment_text(child_node)\n'
#  '            )\n'
#  '\n'
#  '        elif comment_options.scope_method == _ScopeMethod.HTML_END_TAGS:\n'
#  '            tag_name = child_node.metadata["inclusive_scopes"][-1]["name"]\n'
#  '            end_tag = f"</{tag_name}>"\n'
#  '            replacement_txt += "\\n"\n'
#  '            replacement_txt += (\n'
#  '                indentation_char\n'
#  '                * indentation_count_per_lvl\n'
#  '                * (first_indentation_lvl + 1)\n'
#  '                + comment_options.comment_template.format(\n'
#  '                    cls._get_comment_text(child_node)\n'
#  '                )\n'
#  '                + "\\n"\n'
#  '            )\n'
#  '            replacement_txt += (\n'
#  '                indentation_char * indentation_count_per_lvl * '
#  'first_indentation_lvl\n'
#  '                + end_tag\n'
#  '            )\n'
#  '\n'
#  '        else:\n'
#  '            raise KeyError(f"Unrecognized enum value '
#  '{comment_options.scope_method}")\n'
#  '\n'
#  '        return replacement_txt\n'
#  '\n'
#  '    @classmethod\n'
#  '    def _skeletonize(cls, parent_node: TextNode, child_node: TextNode) -> '
#  'None:\n'
#  '        """WARNING: In Place Operation."""\n'
#  '        # Simple protection clauses\n'
#  '        if child_node.text not in parent_node.text:\n'
#  '            raise ValueError("The child text is not contained inside the '
#  'parent text.")\n'
#  '        if child_node.node_id not in (c.node_id for c in '
#  'parent_node.child_nodes or []):\n'
#  '            raise ValueError("The child node is not a child of the parent '
#  'node.")\n'
#  '\n'
#  '        # Now do the replacement\n'
#  '        replacement_text = cls._get_replacement_text(child_node=child_node)\n'
#  '        parent_node.text = parent_node.text.replace(child_node.text, '
#  'replacement_text)\n'
#  '\n'
#  '    @classmethod\n'
#  '    def _skeletonize_list(cls, nodes: List[TextNode]) -> None:\n'
#  "        # Create a convenient map for mapping node id's to nodes\n"
#  '        node_id_map = {n.node_id: n for n in nodes}\n'
#  '\n'
#  '        def recur(node: TextNode) -> None:\n'
#  '            # If any children exist, skeletonize ourselves, starting at the '
#  'root DFS\n'
#  '            for child in node.child_nodes or []:\n'
#  '                child_node = node_id_map[child.node_id]\n'
#  '                cls._skeletonize(parent_node=node, child_node=child_node)\n'
#  '                recur(child_node)\n'
#  '\n'
#  '        # Iterate over root nodes and recur\n'
#  '        for n in nodes:\n'
#  '            if n.parent_node is None:\n'
#  '                recur(n)\n')

# %% [markdown]
# So what are we to do? Well lets try splitting it. We are going to use the `CodeHierarchyNodeParser` to split the nodes into more reasonable chunks.

# %%
split_nodes = CodeHierarchyNodeParser(
    language="python",
    # You can further parameterize the CodeSplitter to split the code
    # into "chunks" that match your context window size using
    # chunck_lines and max_chars parameters, here we just use the defaults
    code_splitter=CodeSplitter(language="python"),
).get_nodes_from_documents(nodes)
len(split_nodes)
# Out:
# 142

# %% [markdown]
# Great! So that split up our data from 8 nodes into 112 nodes! Whats the max length of any of these nodes?

# %%
max(len(n.text) for n in split_nodes)
# Out:
# 1505

# %% [markdown]
# That's much shorter than before! Let's look at a sample.

# %%
pprint(split_nodes[0].text)
# Out:
# ('"""Simple node parser."""\n'
#  'from typing import Callable, List, Optional, Sequence\n'
#  '\n'
#  'from llama_index.bridge.pydantic import Field\n'
#  'from llama_index.callbacks.base import CallbackManager\n'
#  'from llama_index.callbacks.schema import CBEventType, EventPayload\n'
#  'from llama_index.node_parser.extractors.metadata_extractors import '
#  'MetadataExtractor\n'
#  'from llama_index.node_parser.interface import NodeParser\n'
#  'from llama_index.node_parser.node_utils import build_nodes_from_splits\n'
#  'from llama_index.schema import BaseNode, Document\n'
#  'from llama_index.text_splitter.utils import split_by_sentence_tokenizer\n'
#  'from llama_index.utils import get_tqdm_iterable\n'
#  '\n'
#  'DEFAULT_WINDOW_SIZE = 3\n'
#  'DEFAULT_WINDOW_METADATA_KEY = "window"\n'
#  'DEFAULT_OG_TEXT_METADATA_KEY = "original_text"\n'
#  '\n'
#  '\n'
#  'class SentenceWindowNodeParser(NodeParser):\n'
#  '    # Code replaced for brevity. See node_id '
#  'bb5d6cc5-6e08-418c-a685-7cab78ab43dd')

# %% [markdown]
# Without even needing a long printout we can see everything this module imported in the first document (which is at the module level) and the single class it defines. However, now instead of the class body, we see a comment:
#
# `# Code replaced for brevity. See node_id {node_id}`
#
# What if we go to that node_id?
#
# Notice below, that node_id is also in it's `child_nodes`

# %%
split_nodes_by_id = {n.node_id: n for n in split_nodes}
uuid_from_text = split_nodes[0].text.splitlines()[-1].split(" ")[-1]
pprint(split_nodes_by_id[uuid_from_text].text)

assert uuid_from_text in (n.node_id for n in split_nodes[0].child_nodes)
# Out:
# 'class SentenceWindowNodeParser(NodeParser):'

# %% [markdown]
# This is an artefact of the `CodeSplitter`. This must have been a big class! But lets look at it's relationships.

# %%
pprint(split_nodes_by_id[uuid_from_text].relationships)
# Out:
# {<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='bb5d6cc5-6e08-418c-a685-7cab78ab43dd', node_type=<ObjectType.TEXT: '1'>, metadata={'language': 'python', 'inclusive_scopes': [{'name': 'SentenceWindowNodeParser', 'type': 'class_definition', 'signature': 'class SentenceWindowNodeParser(NodeParser):'}], 'filepath': '../../../../llama_index/node_parser/sentence_window.py'}, hash='4278766c3216e33889069110a938de8d8586df6be121586a7eec929470c7d131'),
#  <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='62f836ce-7dba-49b3-be3f-3114fe8dcb00', node_type=<ObjectType.TEXT: '1'>, metadata={'language': 'python', 'inclusive_scopes': [{'name': 'SentenceWindowNodeParser', 'type': 'class_definition', 'signature': 'class SentenceWindowNodeParser(NodeParser):'}], 'filepath': '../../../../llama_index/node_parser/sentence_window.py'}, hash='29a4be710fef2a2fe594805008b2dfeafacd7cb5f19e8b10eef65802c3251128'),
#  <NodeRelationship.PARENT: '4'>: RelatedNodeInfo(node_id='87d12f5a-a1cc-45fb-9732-af69b8ffbcba', node_type=<ObjectType.TEXT: '1'>, metadata={'language': 'python', 'inclusive_scopes': [], 'filepath': '../../../../llama_index/node_parser/sentence_window.py'}, hash='864a71e3715249c5b5b3e4a785ca735141467e1a978cd6ffbd73487e26ddc7e9'),
#  <NodeRelationship.CHILD: '5'>: [RelatedNodeInfo(node_id='ddfaef4f-5d9c-4378-9e53-696704b22505', node_type=<ObjectType.TEXT: '1'>, metadata={'inclusive_scopes': [{'name': 'SentenceWindowNodeParser', 'type': 'class_definition', 'signature': 'class SentenceWindowNodeParser(NodeParser):'}, {'name': '__init__', 'type': 'function_definition', 'signature': 'def __init__(\n        self,\n        sentence_splitter: Optional[Callable[[str], List[str]]] = None,\n        window_size: int = DEFAULT_WINDOW_SIZE,\n        window_metadata_key: str = DEFAULT_WINDOW_METADATA_KEY,\n        original_text_metadata_key: str = DEFAULT_OG_TEXT_METADATA_KEY,\n        include_metadata: bool = True,\n        include_prev_next_rel: bool = True,\n        callback_manager: Optional[CallbackManager] = None,\n        metadata_extractor: Optional[MetadataExtractor] = None,\n    ) -> None:'}]}, hash='2cc7e93cb979cf389d47f92be0e3dae337ebd7ff6d463769a53821db80f85412'),
#                                  RelatedNodeInfo(node_id='7311505b-15f5-43ad-865d-34eae054c594', node_type=<ObjectType.TEXT: '1'>, metadata={'inclusive_scopes': [{'name': 'SentenceWindowNodeParser', 'type': 'class_definition', 'signature': 'class SentenceWindowNodeParser(NodeParser):'}, {'name': 'text_splitter', 'type': 'function_definition', 'signature': 'def text_splitter(self) -> Callable[[str], List[str]]:'}]}, hash='bc867bd67606b314632070c946c41fa2f2b123a182ee2e89ae541e9c428464bd'),
#                                  RelatedNodeInfo(node_id='876c7ed6-303b-4819-92a8-df239ee4e5ab', node_type=<ObjectType.TEXT: '1'>, metadata={'inclusive_scopes': [{'name': 'SentenceWindowNodeParser', 'type': 'class_definition', 'signature': 'class SentenceWindowNodeParser(NodeParser):'}, {'name': 'from_defaults', 'type': 'function_definition', 'signature': 'def from_defaults(\n        cls,\n        sentence_splitter: Optional[Callable[[str], List[str]]] = None,\n        window_size: int = DEFAULT_WINDOW_SIZE,\n        window_metadata_key: str = DEFAULT_WINDOW_METADATA_KEY,\n        original_text_metadata_key: str = DEFAULT_OG_TEXT_METADATA_KEY,\n        include_metadata: bool = True,\n        include_prev_next_rel: bool = True,\n        callback_manager: Optional[CallbackManager] = None,\n        metadata_extractor: Optional[MetadataExtractor] = None,\n    ) -> "SentenceWindowNodeParser":'}]}, hash='6601ea2c560ee8ee2e30815275afed3937d2ca55f735075ca3c03735012fa477'),
#                                  RelatedNodeInfo(node_id='d812f78c-2f42-4464-a822-7d0ff45c03bd', node_type=<ObjectType.TEXT: '1'>, metadata={'inclusive_scopes': [{'name': 'SentenceWindowNodeParser', 'type': 'class_definition', 'signature': 'class SentenceWindowNodeParser(NodeParser):'}, {'name': 'get_nodes_from_documents', 'type': 'function_definition', 'signature': 'def get_nodes_from_documents(\n        self,\n        documents: Sequence[Document],\n        show_progress: bool = False,\n    ) -> List[BaseNode]:'}]}, hash='d0ee8fec1d89a4de0624b1bb8984f34543683dc8d5c0200f0ad1a56d55f01840'),
#                                  RelatedNodeInfo(node_id='a94b30d6-cd12-45d5-8d0f-03c48566a058', node_type=<ObjectType.TEXT: '1'>, metadata={'inclusive_scopes': [{'name': 'SentenceWindowNodeParser', 'type': 'class_definition', 'signature': 'class SentenceWindowNodeParser(NodeParser):'}, {'name': 'build_window_nodes_from_documents', 'type': 'function_definition', 'signature': 'def build_window_nodes_from_documents(\n        self, documents: Sequence[Document]\n    ) -> List[BaseNode]:'}]}, hash='b47c5fb94581ce6682a8a4a75c800904e5a3963966050e97684e72669cbee210')]}

# %% [markdown]
# You see that this node has a `NEXT` relationship, and many children.
#
# If we view it's `NEXT` relationship we will see things as the `CodeSplitter` sees things. Cutting up the node into chunks that are a certain character length. For more information about the `CodeSplitter` read this:
# https://docs.sweep.dev/blogs/chunking-2m-files

# %% [markdown]
# As you can see, the next node was split from this one because of a big docstring!

# %%
from llama_index.schema import NodeRelationship

next_node_relationship_info = split_nodes_by_id[uuid_from_text].relationships[
    NodeRelationship.NEXT
]
next_node = split_nodes_by_id[next_node_relationship_info.node_id]
pprint(next_node.text)
# Out:
# ('"""Sentence window node parser.\n'
#  '\n'
#  '    Splits a document into Nodes, with each node being a sentence.\n'
#  '    Each node contains a window from the surrounding sentences in the '
#  'metadata.\n'
#  '\n'
#  '    Args:\n'
#  '        sentence_splitter (Optional[Callable]): splits text into sentences\n'
#  '        include_metadata (bool): whether to include metadata in nodes\n'
#  '        include_prev_next_rel (bool): whether to include prev/next '
#  'relationships\n'
#  '    """\n'
#  '\n'
#  '    sentence_splitter: Callable[[str], List[str]] = Field(\n'
#  '        default_factory=split_by_sentence_tokenizer,\n'
#  '        description="The text splitter to use when splitting documents.",\n'
#  '        exclude=True,\n'
#  '    )\n'
#  '    window_size: int = Field(\n'
#  '        default=DEFAULT_WINDOW_SIZE,\n'
#  '        description="The number of sentences on each side of a sentence to '
#  'capture.",\n'
#  '    )\n'
#  '    window_metadata_key: str = Field(\n'
#  '        default=DEFAULT_WINDOW_METADATA_KEY,\n'
#  '        description="The metadata key to store the sentence window under.",\n'
#  '    )\n'
#  '    original_text_metadata_key: str = Field(\n'
#  '        default=DEFAULT_OG_TEXT_METADATA_KEY,\n'
#  '        description="The metadata key to store the original sentence in.",\n'
#  '    )\n'
#  '    include_metadata: bool = Field(\n'
#  '        default=True, description="Whether or not to consider metadata when '
#  'splitting."\n'
#  '    )\n'
#  '    include_prev_next_rel: bool = Field(\n'
#  '        default=True, description="Include prev/next node relationships."\n'
#  '    )')

# %% [markdown]
# You can think of the difference between `NodeRelationship.CHILD`/`NodeRelationship.PARENT` and `NodeRelationship.NEXT`/`NodeRelationship.PREVIOUS` as different dimensions.
#
# `CodeHierarchyNodeParser` creates `NodeRelationship.CHILD`/`NodeRelationship.PARENT` between code blocks based on scope hierarchys.
#
# Nodes which are then additionally split by `CodeSplitter` based on context length get an additional `NodeRelationship.NEXT`/`NodeRelationship.PREVIOUS`, and the first node in this chain maintains the `NodeRelationship.CHILD`/`NodeRelationship.PARENT` relationships given to it by `CodeHierarchyNodeParser`
#
# Now what if we explore that first nodes children (`NodeRelationship.CHILD`) are.

# %%
next_node_relationship_info = split_nodes_by_id[uuid_from_text].relationships[
    NodeRelationship.CHILD
][0]
next_node = split_nodes_by_id[next_node_relationship_info.node_id]
pprint(next_node.text)
# Out:
# ('def __init__(\n'
#  '        self,\n'
#  '        sentence_splitter: Optional[Callable[[str], List[str]]] = None,\n'
#  '        window_size: int = DEFAULT_WINDOW_SIZE,\n'
#  '        window_metadata_key: str = DEFAULT_WINDOW_METADATA_KEY,\n'
#  '        original_text_metadata_key: str = DEFAULT_OG_TEXT_METADATA_KEY,\n'
#  '        include_metadata: bool = True,\n'
#  '        include_prev_next_rel: bool = True,\n'
#  '        callback_manager: Optional[CallbackManager] = None,\n'
#  '        metadata_extractor: Optional[MetadataExtractor] = None,\n'
#  '    ) -> None:\n'
#  '        """Init params."""\n'
#  '        callback_manager = callback_manager or CallbackManager([])\n'
#  '        sentence_splitter = sentence_splitter or '
#  'split_by_sentence_tokenizer()\n'
#  '        super().__init__(\n'
#  '            sentence_splitter=sentence_splitter,\n'
#  '            window_size=window_size,\n'
#  '            window_metadata_key=window_metadata_key,\n'
#  '            original_text_metadata_key=original_text_metadata_key,\n'
#  '            include_metadata=include_metadata,\n'
#  '            include_prev_next_rel=include_prev_next_rel,\n'
#  '            callback_manager=callback_manager,\n'
#  '            metadata_extractor=metadata_extractor,\n'
#  '        )')

# %% [markdown]
# The first child of the class is the `__init__` statement! That makes sense.

# %% [markdown]
# # Indices
#
# ## Keyword Table
#
# Lets explore the use of this node parser in an index. We will be able to use any index which allows search by keyword, which should enable us to search for any node by it's uuid, or by any scope name.
#
# Lets use a keyword index to facilitate this kind of operation. We have created a CodeHierarchyKeywordTableIndex which will allow us to search for nodes by their uuid, or by their scope name.

# %%
from llama_index.indices.code_hierarchy import (
    CodeHierarchyKeywordTableIndex,
)

idx = CodeHierarchyKeywordTableIndex(
    nodes=split_nodes,
)
retriever = idx.as_retriever()

# %% [markdown]
# Now we can get the same code as before.

# %%
pprint(retriever.retrieve(uuid_from_text)[0].node.get_content())
# Out:
# 'class SentenceWindowNodeParser(NodeParser):'

# %% [markdown]
# Now what about getting the rest of the code for this scope?

# %%
pprint(
    [
        n.node.get_content()
        for n in retriever.retrieve("SentenceWindowNodeParser")
    ]
)
# Out:
# ['"""Sentence window node parser.\n'
#  '\n'
#  '    Splits a document into Nodes, with each node being a sentence.\n'
#  '    Each node contains a window from the surrounding sentences in the '
#  'metadata.\n'
#  '\n'
#  '    Args:\n'
#  '        sentence_splitter (Optional[Callable]): splits text into sentences\n'
#  '        include_metadata (bool): whether to include metadata in nodes\n'
#  '        include_prev_next_rel (bool): whether to include prev/next '
#  'relationships\n'
#  '    """\n'
#  '\n'
#  '    sentence_splitter: Callable[[str], List[str]] = Field(\n'
#  '        default_factory=split_by_sentence_tokenizer,\n'
#  '        description="The text splitter to use when splitting documents.",\n'
#  '        exclude=True,\n'
#  '    )\n'
#  '    window_size: int = Field(\n'
#  '        default=DEFAULT_WINDOW_SIZE,\n'
#  '        description="The number of sentences on each side of a sentence to '
#  'capture.",\n'
#  '    )\n'
#  '    window_metadata_key: str = Field(\n'
#  '        default=DEFAULT_WINDOW_METADATA_KEY,\n'
#  '        description="The metadata key to store the sentence window under.",\n'
#  '    )\n'
#  '    original_text_metadata_key: str = Field(\n'
#  '        default=DEFAULT_OG_TEXT_METADATA_KEY,\n'
#  '        description="The metadata key to store the original sentence in.",\n'
#  '    )\n'
#  '    include_metadata: bool = Field(\n'
#  '        default=True, description="Whether or not to consider metadata when '
#  'splitting."\n'
#  '    )\n'
#  '    include_prev_next_rel: bool = Field(\n'
#  '        default=True, description="Include prev/next node relationships."\n'
#  '    )',
#  '@classmethod\n'
#  '    def from_defaults(\n'
#  '        cls,\n'
#  '        sentence_splitter: Optional[Callable[[str], List[str]]] = None,\n'
#  '        window_size: int = DEFAULT_WINDOW_SIZE,\n'
#  '        window_metadata_key: str = DEFAULT_WINDOW_METADATA_KEY,\n'
#  '        original_text_metadata_key: str = DEFAULT_OG_TEXT_METADATA_KEY,\n'
#  '        include_metadata: bool = True,\n'
#  '        include_prev_next_rel: bool = True,\n'
#  '        callback_manager: Optional[CallbackManager] = None,\n'
#  '        metadata_extractor: Optional[MetadataExtractor] = None,\n'
#  '    ) -> "SentenceWindowNodeParser":\n'
#  '        # Code replaced for brevity. See node_id '
#  '876c7ed6-303b-4819-92a8-df239ee4e5ab\n'
#  '\n'
#  '    def get_nodes_from_documents(\n'
#  '        self,\n'
#  '        documents: Sequence[Document],\n'
#  '        show_progress: bool = False,\n'
#  '    ) -> List[BaseNode]:\n'
#  '        # Code replaced for brevity. See node_id '
#  'd812f78c-2f42-4464-a822-7d0ff45c03bd\n'
#  '\n'
#  '    def build_window_nodes_from_documents(\n'
#  '        self, documents: Sequence[Document]\n'
#  '    ) -> List[BaseNode]:\n'
#  '        # Code replaced for brevity. See node_id '
#  'a94b30d6-cd12-45d5-8d0f-03c48566a058',
#  'class SentenceWindowNodeParser(NodeParser):',
#  'metadata_extractor: Optional[MetadataExtractor] = Field(\n'
#  '        default=None, description="Metadata extraction pipeline to apply to '
#  'nodes."\n'
#  '    )\n'
#  '    callback_manager: CallbackManager = Field(\n'
#  '        default_factory=CallbackManager, exclude=True\n'
#  '    )\n'
#  '\n'
#  '    def __init__(\n'
#  '        self,\n'
#  '        sentence_splitter: Optional[Callable[[str], List[str]]] = None,\n'
#  '        window_size: int = DEFAULT_WINDOW_SIZE,\n'
#  '        window_metadata_key: str = DEFAULT_WINDOW_METADATA_KEY,\n'
#  '        original_text_metadata_key: str = DEFAULT_OG_TEXT_METADATA_KEY,\n'
#  '        include_metadata: bool = True,\n'
#  '        include_prev_next_rel: bool = True,\n'
#  '        callback_manager: Optional[CallbackManager] = None,\n'
#  '        metadata_extractor: Optional[MetadataExtractor] = None,\n'
#  '    ) -> None:\n'
#  '        # Code replaced for brevity. See node_id '
#  'ddfaef4f-5d9c-4378-9e53-696704b22505\n'
#  '\n'
#  '    @classmethod\n'
#  '    def class_name(cls) -> str:\n'
#  '        return "SentenceWindowNodeParser"\n'
#  '\n'
#  '    @property\n'
#  '    def text_splitter(self) -> Callable[[str], List[str]]:\n'
#  '        # Code replaced for brevity. See node_id '
#  '7311505b-15f5-43ad-865d-34eae054c594']

# %% [markdown]
# The only difficulty is that these are out of order. The CodeSplitter controls how much overlap there is for each of these documents, and how big they are. You can play with its settings to disambiguate any confusion.

# %% [markdown]
# ## Vector Index
#
# You can also use a vector index in the same way, but with a little bit more flexibility to misspellings and such.

# %%
from llama_index.indices.code_hierarchy import (
    CodeHierarchyVectorStoreIndex,
)

idx = CodeHierarchyVectorStoreIndex(
    nodes=split_nodes,
)
retriever = idx.as_retriever()
# Out:
# ---------------------------------------------------------------------------
# LocalProtocolError                        Traceback (most recent call last)
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/httpcore/_exceptions.py:10, in map_exceptions(map)
#       9 try:
# ---> 10     yield
#      11 except Exception as exc:  # noqa: PIE786
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/httpcore/_sync/http11.py:142, in HTTP11Connection._send_request_headers(self, request)
#     141 with map_exceptions({h11.LocalProtocolError: LocalProtocolError}):
# --> 142     event = h11.Request(
#     143         method=request.method,
#     144         target=request.url.target,
#     145         headers=request.headers,
#     146     )
#     147 self._send_event(event, timeout=timeout)
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/h11/_events.py:96, in Request.__init__(self, method, headers, target, http_version, _parsed)
#      94 else:
#      95     object.__setattr__(
# ---> 96         self, "headers", normalize_and_validate(headers, _parsed=_parsed)
#      97     )
#      98 if not _parsed:
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/h11/_headers.py:164, in normalize_and_validate(headers, _parsed)
#     163     validate(_field_name_re, name, "Illegal header name {!r}", name)
# --> 164     validate(_field_value_re, value, "Illegal header value {!r}", value)
#     165 assert isinstance(name, bytes)
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/h11/_util.py:91, in validate(regex, data, msg, *format_args)
#      90         msg = msg.format(*format_args)
# ---> 91     raise LocalProtocolError(msg)
#      92 return match.groupdict()
#
# LocalProtocolError: Illegal header value b'Bearer '
#
# The above exception was the direct cause of the following exception:
#
# LocalProtocolError                        Traceback (most recent call last)
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/httpx/_transports/default.py:66, in map_httpcore_exceptions()
#      65 try:
# ---> 66     yield
#      67 except Exception as exc:
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/httpx/_transports/default.py:228, in HTTPTransport.handle_request(self, request)
#     227 with map_httpcore_exceptions():
# --> 228     resp = self._pool.handle_request(req)
#     230 assert isinstance(resp.stream, typing.Iterable)
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:268, in ConnectionPool.handle_request(self, request)
#     267         self.response_closed(status)
# --> 268     raise exc
#     269 else:
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:251, in ConnectionPool.handle_request(self, request)
#     250 try:
# --> 251     response = connection.handle_request(request)
#     252 except ConnectionNotAvailable:
#     253     # The ConnectionNotAvailable exception is a special case, that
#     254     # indicates we need to retry the request on a new connection.
#    (...)
#     258     # might end up as an HTTP/2 connection, but which actually ends
#     259     # up as HTTP/1.1.
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/httpcore/_sync/connection.py:103, in HTTPConnection.handle_request(self, request)
#     101         raise ConnectionNotAvailable()
# --> 103 return self._connection.handle_request(request)
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/httpcore/_sync/http11.py:133, in HTTP11Connection.handle_request(self, request)
#     132         self._response_closed()
# --> 133 raise exc
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/httpcore/_sync/http11.py:92, in HTTP11Connection.handle_request(self, request)
#      89 with Trace(
#      90     "send_request_headers", logger, request, kwargs
#      91 ) as trace:
# ---> 92     self._send_request_headers(**kwargs)
#      93 with Trace("send_request_body", logger, request, kwargs) as trace:
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/httpcore/_sync/http11.py:141, in HTTP11Connection._send_request_headers(self, request)
#     139 timeout = timeouts.get("write", None)
# --> 141 with map_exceptions({h11.LocalProtocolError: LocalProtocolError}):
#     142     event = h11.Request(
#     143         method=request.method,
#     144         target=request.url.target,
#     145         headers=request.headers,
#     146     )
#
# File ~/.pyenv/versions/3.10.12/lib/python3.10/contextlib.py:153, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     152 try:
# --> 153     self.gen.throw(typ, value, traceback)
#     154 except StopIteration as exc:
#     155     # Suppress StopIteration *unless* it's the same exception that
#     156     # was passed to throw().  This prevents a StopIteration
#     157     # raised inside the "with" statement from being suppressed.
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/httpcore/_exceptions.py:14, in map_exceptions(map)
#      13     if isinstance(exc, from_exc):
# ---> 14         raise to_exc(exc) from exc
#      15 raise
#
# LocalProtocolError: Illegal header value b'Bearer '
#
# The above exception was the direct cause of the following exception:
#
# LocalProtocolError                        Traceback (most recent call last)
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/openai/_base_client.py:858, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     857 try:
# --> 858     response = self._client.send(request, auth=self.custom_auth, stream=stream)
#     859     log.debug(
#     860         'HTTP Request: %s %s "%i %s"', request.method, request.url, response.status_code, response.reason_phrase
#     861     )
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/httpx/_client.py:901, in Client.send(self, request, stream, auth, follow_redirects)
#     899 auth = self._build_request_auth(request, auth)
# --> 901 response = self._send_handling_auth(
#     902     request,
#     903     auth=auth,
#     904     follow_redirects=follow_redirects,
#     905     history=[],
#     906 )
#     907 try:
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/httpx/_client.py:929, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     928 while True:
# --> 929     response = self._send_handling_redirects(
#     930         request,
#     931         follow_redirects=follow_redirects,
#     932         history=history,
#     933     )
#     934     try:
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/httpx/_client.py:966, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     964     hook(request)
# --> 966 response = self._send_single_request(request)
#     967 try:
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/httpx/_client.py:1002, in Client._send_single_request(self, request)
#    1001 with request_context(request=request):
# -> 1002     response = transport.handle_request(request)
#    1004 assert isinstance(response.stream, SyncByteStream)
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/httpx/_transports/default.py:227, in HTTPTransport.handle_request(self, request)
#     215 req = httpcore.Request(
#     216     method=request.method,
#     217     url=httpcore.URL(
#    (...)
#     225     extensions=request.extensions,
#     226 )
# --> 227 with map_httpcore_exceptions():
#     228     resp = self._pool.handle_request(req)
#
# File ~/.pyenv/versions/3.10.12/lib/python3.10/contextlib.py:153, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     152 try:
# --> 153     self.gen.throw(typ, value, traceback)
#     154 except StopIteration as exc:
#     155     # Suppress StopIteration *unless* it's the same exception that
#     156     # was passed to throw().  This prevents a StopIteration
#     157     # raised inside the "with" statement from being suppressed.
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/httpx/_transports/default.py:83, in map_httpcore_exceptions()
#      82 message = str(exc)
# ---> 83 raise mapped_exc(message) from exc
#
# LocalProtocolError: Illegal header value b'Bearer '
#
# During handling of the above exception, another exception occurred:
#
# LocalProtocolError                        Traceback (most recent call last)
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/httpcore/_exceptions.py:10, in map_exceptions(map)
#       9 try:
# ---> 10     yield
#      11 except Exception as exc:  # noqa: PIE786
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/httpcore/_sync/http11.py:142, in HTTP11Connection._send_request_headers(self, request)
#     141 with map_exceptions({h11.LocalProtocolError: LocalProtocolError}):
# --> 142     event = h11.Request(
#     143         method=request.method,
#     144         target=request.url.target,
#     145         headers=request.headers,
#     146     )
#     147 self._send_event(event, timeout=timeout)
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/h11/_events.py:96, in Request.__init__(self, method, headers, target, http_version, _parsed)
#      94 else:
#      95     object.__setattr__(
# ---> 96         self, "headers", normalize_and_validate(headers, _parsed=_parsed)
#      97     )
#      98 if not _parsed:
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/h11/_headers.py:164, in normalize_and_validate(headers, _parsed)
#     163     validate(_field_name_re, name, "Illegal header name {!r}", name)
# --> 164     validate(_field_value_re, value, "Illegal header value {!r}", value)
#     165 assert isinstance(name, bytes)
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/h11/_util.py:91, in validate(regex, data, msg, *format_args)
#      90         msg = msg.format(*format_args)
# ---> 91     raise LocalProtocolError(msg)
#      92 return match.groupdict()
#
# LocalProtocolError: Illegal header value b'Bearer '
#
# The above exception was the direct cause of the following exception:
#
# LocalProtocolError                        Traceback (most recent call last)
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/httpx/_transports/default.py:66, in map_httpcore_exceptions()
#      65 try:
# ---> 66     yield
#      67 except Exception as exc:
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/httpx/_transports/default.py:228, in HTTPTransport.handle_request(self, request)
#     227 with map_httpcore_exceptions():
# --> 228     resp = self._pool.handle_request(req)
#     230 assert isinstance(resp.stream, typing.Iterable)
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:268, in ConnectionPool.handle_request(self, request)
#     267         self.response_closed(status)
# --> 268     raise exc
#     269 else:
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:251, in ConnectionPool.handle_request(self, request)
#     250 try:
# --> 251     response = connection.handle_request(request)
#     252 except ConnectionNotAvailable:
#     253     # The ConnectionNotAvailable exception is a special case, that
#     254     # indicates we need to retry the request on a new connection.
#    (...)
#     258     # might end up as an HTTP/2 connection, but which actually ends
#     259     # up as HTTP/1.1.
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/httpcore/_sync/connection.py:103, in HTTPConnection.handle_request(self, request)
#     101         raise ConnectionNotAvailable()
# --> 103 return self._connection.handle_request(request)
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/httpcore/_sync/http11.py:133, in HTTP11Connection.handle_request(self, request)
#     132         self._response_closed()
# --> 133 raise exc
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/httpcore/_sync/http11.py:92, in HTTP11Connection.handle_request(self, request)
#      89 with Trace(
#      90     "send_request_headers", logger, request, kwargs
#      91 ) as trace:
# ---> 92     self._send_request_headers(**kwargs)
#      93 with Trace("send_request_body", logger, request, kwargs) as trace:
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/httpcore/_sync/http11.py:141, in HTTP11Connection._send_request_headers(self, request)
#     139 timeout = timeouts.get("write", None)
# --> 141 with map_exceptions({h11.LocalProtocolError: LocalProtocolError}):
#     142     event = h11.Request(
#     143         method=request.method,
#     144         target=request.url.target,
#     145         headers=request.headers,
#     146     )
#
# File ~/.pyenv/versions/3.10.12/lib/python3.10/contextlib.py:153, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     152 try:
# --> 153     self.gen.throw(typ, value, traceback)
#     154 except StopIteration as exc:
#     155     # Suppress StopIteration *unless* it's the same exception that
#     156     # was passed to throw().  This prevents a StopIteration
#     157     # raised inside the "with" statement from being suppressed.
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/httpcore/_exceptions.py:14, in map_exceptions(map)
#      13     if isinstance(exc, from_exc):
# ---> 14         raise to_exc(exc) from exc
#      15 raise
#
# LocalProtocolError: Illegal header value b'Bearer '
#
# The above exception was the direct cause of the following exception:
#
# LocalProtocolError                        Traceback (most recent call last)
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/openai/_base_client.py:858, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     857 try:
# --> 858     response = self._client.send(request, auth=self.custom_auth, stream=stream)
#     859     log.debug(
#     860         'HTTP Request: %s %s "%i %s"', request.method, request.url, response.status_code, response.reason_phrase
#     861     )
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/httpx/_client.py:901, in Client.send(self, request, stream, auth, follow_redirects)
#     899 auth = self._build_request_auth(request, auth)
# --> 901 response = self._send_handling_auth(
#     902     request,
#     903     auth=auth,
#     904     follow_redirects=follow_redirects,
#     905     history=[],
#     906 )
#     907 try:
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/httpx/_client.py:929, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     928 while True:
# --> 929     response = self._send_handling_redirects(
#     930         request,
#     931         follow_redirects=follow_redirects,
#     932         history=history,
#     933     )
#     934     try:
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/httpx/_client.py:966, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     964     hook(request)
# --> 966 response = self._send_single_request(request)
#     967 try:
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/httpx/_client.py:1002, in Client._send_single_request(self, request)
#    1001 with request_context(request=request):
# -> 1002     response = transport.handle_request(request)
#    1004 assert isinstance(response.stream, SyncByteStream)
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/httpx/_transports/default.py:227, in HTTPTransport.handle_request(self, request)
#     215 req = httpcore.Request(
#     216     method=request.method,
#     217     url=httpcore.URL(
#    (...)
#     225     extensions=request.extensions,
#     226 )
# --> 227 with map_httpcore_exceptions():
#     228     resp = self._pool.handle_request(req)
#
# File ~/.pyenv/versions/3.10.12/lib/python3.10/contextlib.py:153, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     152 try:
# --> 153     self.gen.throw(typ, value, traceback)
#     154 except StopIteration as exc:
#     155     # Suppress StopIteration *unless* it's the same exception that
#     156     # was passed to throw().  This prevents a StopIteration
#     157     # raised inside the "with" statement from being suppressed.
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/httpx/_transports/default.py:83, in map_httpcore_exceptions()
#      82 message = str(exc)
# ---> 83 raise mapped_exc(message) from exc
#
# LocalProtocolError: Illegal header value b'Bearer '
#
# During handling of the above exception, another exception occurred:
#
# LocalProtocolError                        Traceback (most recent call last)
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/httpcore/_exceptions.py:10, in map_exceptions(map)
#       9 try:
# ---> 10     yield
#      11 except Exception as exc:  # noqa: PIE786
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/httpcore/_sync/http11.py:142, in HTTP11Connection._send_request_headers(self, request)
#     141 with map_exceptions({h11.LocalProtocolError: LocalProtocolError}):
# --> 142     event = h11.Request(
#     143         method=request.method,
#     144         target=request.url.target,
#     145         headers=request.headers,
#     146     )
#     147 self._send_event(event, timeout=timeout)
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/h11/_events.py:96, in Request.__init__(self, method, headers, target, http_version, _parsed)
#      94 else:
#      95     object.__setattr__(
# ---> 96         self, "headers", normalize_and_validate(headers, _parsed=_parsed)
#      97     )
#      98 if not _parsed:
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/h11/_headers.py:164, in normalize_and_validate(headers, _parsed)
#     163     validate(_field_name_re, name, "Illegal header name {!r}", name)
# --> 164     validate(_field_value_re, value, "Illegal header value {!r}", value)
#     165 assert isinstance(name, bytes)
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/h11/_util.py:91, in validate(regex, data, msg, *format_args)
#      90         msg = msg.format(*format_args)
# ---> 91     raise LocalProtocolError(msg)
#      92 return match.groupdict()
#
# LocalProtocolError: Illegal header value b'Bearer '
#
# The above exception was the direct cause of the following exception:
#
# LocalProtocolError                        Traceback (most recent call last)
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/httpx/_transports/default.py:66, in map_httpcore_exceptions()
#      65 try:
# ---> 66     yield
#      67 except Exception as exc:
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/httpx/_transports/default.py:228, in HTTPTransport.handle_request(self, request)
#     227 with map_httpcore_exceptions():
# --> 228     resp = self._pool.handle_request(req)
#     230 assert isinstance(resp.stream, typing.Iterable)
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:268, in ConnectionPool.handle_request(self, request)
#     267         self.response_closed(status)
# --> 268     raise exc
#     269 else:
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:251, in ConnectionPool.handle_request(self, request)
#     250 try:
# --> 251     response = connection.handle_request(request)
#     252 except ConnectionNotAvailable:
#     253     # The ConnectionNotAvailable exception is a special case, that
#     254     # indicates we need to retry the request on a new connection.
#    (...)
#     258     # might end up as an HTTP/2 connection, but which actually ends
#     259     # up as HTTP/1.1.
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/httpcore/_sync/connection.py:103, in HTTPConnection.handle_request(self, request)
#     101         raise ConnectionNotAvailable()
# --> 103 return self._connection.handle_request(request)
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/httpcore/_sync/http11.py:133, in HTTP11Connection.handle_request(self, request)
#     132         self._response_closed()
# --> 133 raise exc
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/httpcore/_sync/http11.py:92, in HTTP11Connection.handle_request(self, request)
#      89 with Trace(
#      90     "send_request_headers", logger, request, kwargs
#      91 ) as trace:
# ---> 92     self._send_request_headers(**kwargs)
#      93 with Trace("send_request_body", logger, request, kwargs) as trace:
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/httpcore/_sync/http11.py:141, in HTTP11Connection._send_request_headers(self, request)
#     139 timeout = timeouts.get("write", None)
# --> 141 with map_exceptions({h11.LocalProtocolError: LocalProtocolError}):
#     142     event = h11.Request(
#     143         method=request.method,
#     144         target=request.url.target,
#     145         headers=request.headers,
#     146     )
#
# File ~/.pyenv/versions/3.10.12/lib/python3.10/contextlib.py:153, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     152 try:
# --> 153     self.gen.throw(typ, value, traceback)
#     154 except StopIteration as exc:
#     155     # Suppress StopIteration *unless* it's the same exception that
#     156     # was passed to throw().  This prevents a StopIteration
#     157     # raised inside the "with" statement from being suppressed.
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/httpcore/_exceptions.py:14, in map_exceptions(map)
#      13     if isinstance(exc, from_exc):
# ---> 14         raise to_exc(exc) from exc
#      15 raise
#
# LocalProtocolError: Illegal header value b'Bearer '
#
# The above exception was the direct cause of the following exception:
#
# LocalProtocolError                        Traceback (most recent call last)
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/openai/_base_client.py:858, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     857 try:
# --> 858     response = self._client.send(request, auth=self.custom_auth, stream=stream)
#     859     log.debug(
#     860         'HTTP Request: %s %s "%i %s"', request.method, request.url, response.status_code, response.reason_phrase
#     861     )
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/httpx/_client.py:901, in Client.send(self, request, stream, auth, follow_redirects)
#     899 auth = self._build_request_auth(request, auth)
# --> 901 response = self._send_handling_auth(
#     902     request,
#     903     auth=auth,
#     904     follow_redirects=follow_redirects,
#     905     history=[],
#     906 )
#     907 try:
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/httpx/_client.py:929, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     928 while True:
# --> 929     response = self._send_handling_redirects(
#     930         request,
#     931         follow_redirects=follow_redirects,
#     932         history=history,
#     933     )
#     934     try:
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/httpx/_client.py:966, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     964     hook(request)
# --> 966 response = self._send_single_request(request)
#     967 try:
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/httpx/_client.py:1002, in Client._send_single_request(self, request)
#    1001 with request_context(request=request):
# -> 1002     response = transport.handle_request(request)
#    1004 assert isinstance(response.stream, SyncByteStream)
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/httpx/_transports/default.py:227, in HTTPTransport.handle_request(self, request)
#     215 req = httpcore.Request(
#     216     method=request.method,
#     217     url=httpcore.URL(
#    (...)
#     225     extensions=request.extensions,
#     226 )
# --> 227 with map_httpcore_exceptions():
#     228     resp = self._pool.handle_request(req)
#
# File ~/.pyenv/versions/3.10.12/lib/python3.10/contextlib.py:153, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     152 try:
# --> 153     self.gen.throw(typ, value, traceback)
#     154 except StopIteration as exc:
#     155     # Suppress StopIteration *unless* it's the same exception that
#     156     # was passed to throw().  This prevents a StopIteration
#     157     # raised inside the "with" statement from being suppressed.
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/httpx/_transports/default.py:83, in map_httpcore_exceptions()
#      82 message = str(exc)
# ---> 83 raise mapped_exc(message) from exc
#
# LocalProtocolError: Illegal header value b'Bearer '
#
# During handling of the above exception, another exception occurred:
#
# LocalProtocolError                        Traceback (most recent call last)
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/httpcore/_exceptions.py:10, in map_exceptions(map)
#       9 try:
# ---> 10     yield
#      11 except Exception as exc:  # noqa: PIE786
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/httpcore/_sync/http11.py:142, in HTTP11Connection._send_request_headers(self, request)
#     141 with map_exceptions({h11.LocalProtocolError: LocalProtocolError}):
# --> 142     event = h11.Request(
#     143         method=request.method,
#     144         target=request.url.target,
#     145         headers=request.headers,
#     146     )
#     147 self._send_event(event, timeout=timeout)
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/h11/_events.py:96, in Request.__init__(self, method, headers, target, http_version, _parsed)
#      94 else:
#      95     object.__setattr__(
# ---> 96         self, "headers", normalize_and_validate(headers, _parsed=_parsed)
#      97     )
#      98 if not _parsed:
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/h11/_headers.py:164, in normalize_and_validate(headers, _parsed)
#     163     validate(_field_name_re, name, "Illegal header name {!r}", name)
# --> 164     validate(_field_value_re, value, "Illegal header value {!r}", value)
#     165 assert isinstance(name, bytes)
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/h11/_util.py:91, in validate(regex, data, msg, *format_args)
#      90         msg = msg.format(*format_args)
# ---> 91     raise LocalProtocolError(msg)
#      92 return match.groupdict()
#
# LocalProtocolError: Illegal header value b'Bearer '
#
# The above exception was the direct cause of the following exception:
#
# LocalProtocolError                        Traceback (most recent call last)
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/httpx/_transports/default.py:66, in map_httpcore_exceptions()
#      65 try:
# ---> 66     yield
#      67 except Exception as exc:
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/httpx/_transports/default.py:228, in HTTPTransport.handle_request(self, request)
#     227 with map_httpcore_exceptions():
# --> 228     resp = self._pool.handle_request(req)
#     230 assert isinstance(resp.stream, typing.Iterable)
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:268, in ConnectionPool.handle_request(self, request)
#     267         self.response_closed(status)
# --> 268     raise exc
#     269 else:
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:251, in ConnectionPool.handle_request(self, request)
#     250 try:
# --> 251     response = connection.handle_request(request)
#     252 except ConnectionNotAvailable:
#     253     # The ConnectionNotAvailable exception is a special case, that
#     254     # indicates we need to retry the request on a new connection.
#    (...)
#     258     # might end up as an HTTP/2 connection, but which actually ends
#     259     # up as HTTP/1.1.
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/httpcore/_sync/connection.py:103, in HTTPConnection.handle_request(self, request)
#     101         raise ConnectionNotAvailable()
# --> 103 return self._connection.handle_request(request)
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/httpcore/_sync/http11.py:133, in HTTP11Connection.handle_request(self, request)
#     132         self._response_closed()
# --> 133 raise exc
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/httpcore/_sync/http11.py:92, in HTTP11Connection.handle_request(self, request)
#      89 with Trace(
#      90     "send_request_headers", logger, request, kwargs
#      91 ) as trace:
# ---> 92     self._send_request_headers(**kwargs)
#      93 with Trace("send_request_body", logger, request, kwargs) as trace:
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/httpcore/_sync/http11.py:141, in HTTP11Connection._send_request_headers(self, request)
#     139 timeout = timeouts.get("write", None)
# --> 141 with map_exceptions({h11.LocalProtocolError: LocalProtocolError}):
#     142     event = h11.Request(
#     143         method=request.method,
#     144         target=request.url.target,
#     145         headers=request.headers,
#     146     )
#
# File ~/.pyenv/versions/3.10.12/lib/python3.10/contextlib.py:153, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     152 try:
# --> 153     self.gen.throw(typ, value, traceback)
#     154 except StopIteration as exc:
#     155     # Suppress StopIteration *unless* it's the same exception that
#     156     # was passed to throw().  This prevents a StopIteration
#     157     # raised inside the "with" statement from being suppressed.
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/httpcore/_exceptions.py:14, in map_exceptions(map)
#      13     if isinstance(exc, from_exc):
# ---> 14         raise to_exc(exc) from exc
#      15 raise
#
# LocalProtocolError: Illegal header value b'Bearer '
#
# The above exception was the direct cause of the following exception:
#
# LocalProtocolError                        Traceback (most recent call last)
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/openai/_base_client.py:858, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     857 try:
# --> 858     response = self._client.send(request, auth=self.custom_auth, stream=stream)
#     859     log.debug(
#     860         'HTTP Request: %s %s "%i %s"', request.method, request.url, response.status_code, response.reason_phrase
#     861     )
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/httpx/_client.py:901, in Client.send(self, request, stream, auth, follow_redirects)
#     899 auth = self._build_request_auth(request, auth)
# --> 901 response = self._send_handling_auth(
#     902     request,
#     903     auth=auth,
#     904     follow_redirects=follow_redirects,
#     905     history=[],
#     906 )
#     907 try:
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/httpx/_client.py:929, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     928 while True:
# --> 929     response = self._send_handling_redirects(
#     930         request,
#     931         follow_redirects=follow_redirects,
#     932         history=history,
#     933     )
#     934     try:
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/httpx/_client.py:966, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     964     hook(request)
# --> 966 response = self._send_single_request(request)
#     967 try:
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/httpx/_client.py:1002, in Client._send_single_request(self, request)
#    1001 with request_context(request=request):
# -> 1002     response = transport.handle_request(request)
#    1004 assert isinstance(response.stream, SyncByteStream)
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/httpx/_transports/default.py:227, in HTTPTransport.handle_request(self, request)
#     215 req = httpcore.Request(
#     216     method=request.method,
#     217     url=httpcore.URL(
#    (...)
#     225     extensions=request.extensions,
#     226 )
# --> 227 with map_httpcore_exceptions():
#     228     resp = self._pool.handle_request(req)
#
# File ~/.pyenv/versions/3.10.12/lib/python3.10/contextlib.py:153, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     152 try:
# --> 153     self.gen.throw(typ, value, traceback)
#     154 except StopIteration as exc:
#     155     # Suppress StopIteration *unless* it's the same exception that
#     156     # was passed to throw().  This prevents a StopIteration
#     157     # raised inside the "with" statement from being suppressed.
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/httpx/_transports/default.py:83, in map_httpcore_exceptions()
#      82 message = str(exc)
# ---> 83 raise mapped_exc(message) from exc
#
# LocalProtocolError: Illegal header value b'Bearer '
#
# During handling of the above exception, another exception occurred:
#
# LocalProtocolError                        Traceback (most recent call last)
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/httpcore/_exceptions.py:10, in map_exceptions(map)
#       9 try:
# ---> 10     yield
#      11 except Exception as exc:  # noqa: PIE786
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/httpcore/_sync/http11.py:142, in HTTP11Connection._send_request_headers(self, request)
#     141 with map_exceptions({h11.LocalProtocolError: LocalProtocolError}):
# --> 142     event = h11.Request(
#     143         method=request.method,
#     144         target=request.url.target,
#     145         headers=request.headers,
#     146     )
#     147 self._send_event(event, timeout=timeout)
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/h11/_events.py:96, in Request.__init__(self, method, headers, target, http_version, _parsed)
#      94 else:
#      95     object.__setattr__(
# ---> 96         self, "headers", normalize_and_validate(headers, _parsed=_parsed)
#      97     )
#      98 if not _parsed:
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/h11/_headers.py:164, in normalize_and_validate(headers, _parsed)
#     163     validate(_field_name_re, name, "Illegal header name {!r}", name)
# --> 164     validate(_field_value_re, value, "Illegal header value {!r}", value)
#     165 assert isinstance(name, bytes)
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/h11/_util.py:91, in validate(regex, data, msg, *format_args)
#      90         msg = msg.format(*format_args)
# ---> 91     raise LocalProtocolError(msg)
#      92 return match.groupdict()
#
# LocalProtocolError: Illegal header value b'Bearer '
#
# The above exception was the direct cause of the following exception:
#
# LocalProtocolError                        Traceback (most recent call last)
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/httpx/_transports/default.py:66, in map_httpcore_exceptions()
#      65 try:
# ---> 66     yield
#      67 except Exception as exc:
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/httpx/_transports/default.py:228, in HTTPTransport.handle_request(self, request)
#     227 with map_httpcore_exceptions():
# --> 228     resp = self._pool.handle_request(req)
#     230 assert isinstance(resp.stream, typing.Iterable)
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:268, in ConnectionPool.handle_request(self, request)
#     267         self.response_closed(status)
# --> 268     raise exc
#     269 else:
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:251, in ConnectionPool.handle_request(self, request)
#     250 try:
# --> 251     response = connection.handle_request(request)
#     252 except ConnectionNotAvailable:
#     253     # The ConnectionNotAvailable exception is a special case, that
#     254     # indicates we need to retry the request on a new connection.
#    (...)
#     258     # might end up as an HTTP/2 connection, but which actually ends
#     259     # up as HTTP/1.1.
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/httpcore/_sync/connection.py:103, in HTTPConnection.handle_request(self, request)
#     101         raise ConnectionNotAvailable()
# --> 103 return self._connection.handle_request(request)
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/httpcore/_sync/http11.py:133, in HTTP11Connection.handle_request(self, request)
#     132         self._response_closed()
# --> 133 raise exc
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/httpcore/_sync/http11.py:92, in HTTP11Connection.handle_request(self, request)
#      89 with Trace(
#      90     "send_request_headers", logger, request, kwargs
#      91 ) as trace:
# ---> 92     self._send_request_headers(**kwargs)
#      93 with Trace("send_request_body", logger, request, kwargs) as trace:
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/httpcore/_sync/http11.py:141, in HTTP11Connection._send_request_headers(self, request)
#     139 timeout = timeouts.get("write", None)
# --> 141 with map_exceptions({h11.LocalProtocolError: LocalProtocolError}):
#     142     event = h11.Request(
#     143         method=request.method,
#     144         target=request.url.target,
#     145         headers=request.headers,
#     146     )
#
# File ~/.pyenv/versions/3.10.12/lib/python3.10/contextlib.py:153, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     152 try:
# --> 153     self.gen.throw(typ, value, traceback)
#     154 except StopIteration as exc:
#     155     # Suppress StopIteration *unless* it's the same exception that
#     156     # was passed to throw().  This prevents a StopIteration
#     157     # raised inside the "with" statement from being suppressed.
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/httpcore/_exceptions.py:14, in map_exceptions(map)
#      13     if isinstance(exc, from_exc):
# ---> 14         raise to_exc(exc) from exc
#      15 raise
#
# LocalProtocolError: Illegal header value b'Bearer '
#
# The above exception was the direct cause of the following exception:
#
# LocalProtocolError                        Traceback (most recent call last)
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/openai/_base_client.py:858, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     857 try:
# --> 858     response = self._client.send(request, auth=self.custom_auth, stream=stream)
#     859     log.debug(
#     860         'HTTP Request: %s %s "%i %s"', request.method, request.url, response.status_code, response.reason_phrase
#     861     )
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/httpx/_client.py:901, in Client.send(self, request, stream, auth, follow_redirects)
#     899 auth = self._build_request_auth(request, auth)
# --> 901 response = self._send_handling_auth(
#     902     request,
#     903     auth=auth,
#     904     follow_redirects=follow_redirects,
#     905     history=[],
#     906 )
#     907 try:
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/httpx/_client.py:929, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     928 while True:
# --> 929     response = self._send_handling_redirects(
#     930         request,
#     931         follow_redirects=follow_redirects,
#     932         history=history,
#     933     )
#     934     try:
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/httpx/_client.py:966, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     964     hook(request)
# --> 966 response = self._send_single_request(request)
#     967 try:
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/httpx/_client.py:1002, in Client._send_single_request(self, request)
#    1001 with request_context(request=request):
# -> 1002     response = transport.handle_request(request)
#    1004 assert isinstance(response.stream, SyncByteStream)
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/httpx/_transports/default.py:227, in HTTPTransport.handle_request(self, request)
#     215 req = httpcore.Request(
#     216     method=request.method,
#     217     url=httpcore.URL(
#    (...)
#     225     extensions=request.extensions,
#     226 )
# --> 227 with map_httpcore_exceptions():
#     228     resp = self._pool.handle_request(req)
#
# File ~/.pyenv/versions/3.10.12/lib/python3.10/contextlib.py:153, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     152 try:
# --> 153     self.gen.throw(typ, value, traceback)
#     154 except StopIteration as exc:
#     155     # Suppress StopIteration *unless* it's the same exception that
#     156     # was passed to throw().  This prevents a StopIteration
#     157     # raised inside the "with" statement from being suppressed.
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/httpx/_transports/default.py:83, in map_httpcore_exceptions()
#      82 message = str(exc)
# ---> 83 raise mapped_exc(message) from exc
#
# LocalProtocolError: Illegal header value b'Bearer '
#
# During handling of the above exception, another exception occurred:
#
# LocalProtocolError                        Traceback (most recent call last)
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/httpcore/_exceptions.py:10, in map_exceptions(map)
#       9 try:
# ---> 10     yield
#      11 except Exception as exc:  # noqa: PIE786
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/httpcore/_sync/http11.py:142, in HTTP11Connection._send_request_headers(self, request)
#     141 with map_exceptions({h11.LocalProtocolError: LocalProtocolError}):
# --> 142     event = h11.Request(
#     143         method=request.method,
#     144         target=request.url.target,
#     145         headers=request.headers,
#     146     )
#     147 self._send_event(event, timeout=timeout)
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/h11/_events.py:96, in Request.__init__(self, method, headers, target, http_version, _parsed)
#      94 else:
#      95     object.__setattr__(
# ---> 96         self, "headers", normalize_and_validate(headers, _parsed=_parsed)
#      97     )
#      98 if not _parsed:
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/h11/_headers.py:164, in normalize_and_validate(headers, _parsed)
#     163     validate(_field_name_re, name, "Illegal header name {!r}", name)
# --> 164     validate(_field_value_re, value, "Illegal header value {!r}", value)
#     165 assert isinstance(name, bytes)
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/h11/_util.py:91, in validate(regex, data, msg, *format_args)
#      90         msg = msg.format(*format_args)
# ---> 91     raise LocalProtocolError(msg)
#      92 return match.groupdict()
#
# LocalProtocolError: Illegal header value b'Bearer '
#
# The above exception was the direct cause of the following exception:
#
# LocalProtocolError                        Traceback (most recent call last)
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/httpx/_transports/default.py:66, in map_httpcore_exceptions()
#      65 try:
# ---> 66     yield
#      67 except Exception as exc:
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/httpx/_transports/default.py:228, in HTTPTransport.handle_request(self, request)
#     227 with map_httpcore_exceptions():
# --> 228     resp = self._pool.handle_request(req)
#     230 assert isinstance(resp.stream, typing.Iterable)
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:268, in ConnectionPool.handle_request(self, request)
#     267         self.response_closed(status)
# --> 268     raise exc
#     269 else:
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:251, in ConnectionPool.handle_request(self, request)
#     250 try:
# --> 251     response = connection.handle_request(request)
#     252 except ConnectionNotAvailable:
#     253     # The ConnectionNotAvailable exception is a special case, that
#     254     # indicates we need to retry the request on a new connection.
#    (...)
#     258     # might end up as an HTTP/2 connection, but which actually ends
#     259     # up as HTTP/1.1.
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/httpcore/_sync/connection.py:103, in HTTPConnection.handle_request(self, request)
#     101         raise ConnectionNotAvailable()
# --> 103 return self._connection.handle_request(request)
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/httpcore/_sync/http11.py:133, in HTTP11Connection.handle_request(self, request)
#     132         self._response_closed()
# --> 133 raise exc
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/httpcore/_sync/http11.py:92, in HTTP11Connection.handle_request(self, request)
#      89 with Trace(
#      90     "send_request_headers", logger, request, kwargs
#      91 ) as trace:
# ---> 92     self._send_request_headers(**kwargs)
#      93 with Trace("send_request_body", logger, request, kwargs) as trace:
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/httpcore/_sync/http11.py:141, in HTTP11Connection._send_request_headers(self, request)
#     139 timeout = timeouts.get("write", None)
# --> 141 with map_exceptions({h11.LocalProtocolError: LocalProtocolError}):
#     142     event = h11.Request(
#     143         method=request.method,
#     144         target=request.url.target,
#     145         headers=request.headers,
#     146     )
#
# File ~/.pyenv/versions/3.10.12/lib/python3.10/contextlib.py:153, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     152 try:
# --> 153     self.gen.throw(typ, value, traceback)
#     154 except StopIteration as exc:
#     155     # Suppress StopIteration *unless* it's the same exception that
#     156     # was passed to throw().  This prevents a StopIteration
#     157     # raised inside the "with" statement from being suppressed.
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/httpcore/_exceptions.py:14, in map_exceptions(map)
#      13     if isinstance(exc, from_exc):
# ---> 14         raise to_exc(exc) from exc
#      15 raise
#
# LocalProtocolError: Illegal header value b'Bearer '
#
# The above exception was the direct cause of the following exception:
#
# LocalProtocolError                        Traceback (most recent call last)
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/openai/_base_client.py:858, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     857 try:
# --> 858     response = self._client.send(request, auth=self.custom_auth, stream=stream)
#     859     log.debug(
#     860         'HTTP Request: %s %s "%i %s"', request.method, request.url, response.status_code, response.reason_phrase
#     861     )
#
# ...
#       <a href='vscode-notebook-cell:/Users/ryan.peach/Documents/ryanpeach/llama_index/docs/examples/node_parsers/code_hierarchy/CodeHierarchyNodeParserUsage.ipynb#Y240sZmlsZQ%3D%3D?line=2'>3</a> )
# ----> <a href='vscode-notebook-cell:/Users/ryan.peach/Documents/ryanpeach/llama_index/docs/examples/node_parsers/code_hierarchy/CodeHierarchyNodeParserUsage.ipynb#Y240sZmlsZQ%3D%3D?line=4'>5</a> idx = CodeHierarchyVectorStoreIndex(
#       <a href='vscode-notebook-cell:/Users/ryan.peach/Documents/ryanpeach/llama_index/docs/examples/node_parsers/code_hierarchy/CodeHierarchyNodeParserUsage.ipynb#Y240sZmlsZQ%3D%3D?line=5'>6</a>     nodes=split_nodes,
#       <a href='vscode-notebook-cell:/Users/ryan.peach/Documents/ryanpeach/llama_index/docs/examples/node_parsers/code_hierarchy/CodeHierarchyNodeParserUsage.ipynb#Y240sZmlsZQ%3D%3D?line=6'>7</a> )
#       <a href='vscode-notebook-cell:/Users/ryan.peach/Documents/ryanpeach/llama_index/docs/examples/node_parsers/code_hierarchy/CodeHierarchyNodeParserUsage.ipynb#Y240sZmlsZQ%3D%3D?line=7'>8</a> retriever = idx.as_retriever()
#
# File ~/Documents/ryanpeach/llama_index/llama_index/indices/vector_store/base.py:49, in VectorStoreIndex.__init__(self, nodes, index_struct, service_context, storage_context, use_async, store_nodes_override, show_progress, **kwargs)
#      47 self._use_async = use_async
#      48 self._store_nodes_override = store_nodes_override
# ---> 49 super().__init__(
#      50     nodes=nodes,
#      51     index_struct=index_struct,
#      52     service_context=service_context,
#      53     storage_context=storage_context,
#      54     show_progress=show_progress,
#      55     **kwargs,
#      56 )
#
# File ~/Documents/ryanpeach/llama_index/llama_index/indices/base.py:71, in BaseIndex.__init__(self, nodes, index_struct, storage_context, service_context, show_progress, **kwargs)
#      69 if index_struct is None:
#      70     assert nodes is not None
# ---> 71     index_struct = self.build_index_from_nodes(nodes)
#      72 self._index_struct = index_struct
#      73 self._storage_context.index_store.add_index_struct(self._index_struct)
#
# File ~/Documents/ryanpeach/llama_index/llama_index/indices/vector_store/base.py:254, in VectorStoreIndex.build_index_from_nodes(self, nodes, **insert_kwargs)
#     243 def build_index_from_nodes(
#     244     self,
#     245     nodes: Sequence[BaseNode],
#     246     **insert_kwargs: Any,
#     247 ) -> IndexDict:
#     248     """Build the index from nodes.
#     249
#     250     NOTE: Overrides BaseIndex.build_index_from_nodes.
#     251         VectorStoreIndex only stores nodes in document store
#     252         if vector store does not store text
#     253     """
# --> 254     return self._build_index_from_nodes(nodes, **insert_kwargs)
#
# File ~/Documents/ryanpeach/llama_index/llama_index/indices/vector_store/base.py:235, in VectorStoreIndex._build_index_from_nodes(self, nodes, **insert_kwargs)
#     233     run_async_tasks(tasks)
#     234 else:
# --> 235     self._add_nodes_to_index(
#     236         index_struct,
#     237         nodes,
#     238         show_progress=self._show_progress,
#     239         **insert_kwargs,
#     240     )
#     241 return index_struct
#
# File ~/Documents/ryanpeach/llama_index/llama_index/indices/vector_store/base.py:188, in VectorStoreIndex._add_nodes_to_index(self, index_struct, nodes, show_progress, **insert_kwargs)
#     185 if not nodes:
#     186     return
# --> 188 nodes = self._get_node_with_embedding(nodes, show_progress)
#     189 new_ids = self._vector_store.add(nodes, **insert_kwargs)
#     191 if not self._vector_store.stores_text or self._store_nodes_override:
#     192     # NOTE: if the vector store doesn't store text,
#     193     # we need to add the nodes to the index struct and document store
#
# File ~/Documents/ryanpeach/llama_index/llama_index/indices/code_hierarchy.py:179, in CodeHierarchyVectorStoreIndex._get_node_with_embedding(self, nodes, show_progress)
#     168 def _get_node_with_embedding(
#     169     self,
#     170     nodes: Sequence[BaseNode],
#     171     show_progress: bool = False,
#     172 ) -> List[BaseNode]:
#     173     """Get tuples of id, node, and embedding.
#     174
#     175     Allows us to store these nodes in a vector store.
#     176     Embeddings are called in batches.
#     177
#     178     """
# --> 179     id_to_embed_map = _embed_nodes(
#     180         nodes=nodes,
#     181         embed_model=self._service_context.embed_model,
#     182         show_progress=show_progress,
#     183     )
#     185     results = []
#     186     for node in nodes:
#
# File ~/Documents/ryanpeach/llama_index/llama_index/indices/code_hierarchy.py:149, in _embed_nodes(nodes, embed_model, show_progress)
#     139 """Get embeddings of the given nodes, run embedding model if necessary.
#     140
#     141 Args:
#    (...)
#     145
#     146 """
#     147 id_to_embed_map, texts_to_embed, ids_to_embed = _get_id_to_embed_map(nodes)
# --> 149 new_embeddings = embed_model.get_text_embedding_batch(
#     150     texts_to_embed, show_progress=show_progress
#     151 )
#     153 for new_id, text_embedding in zip(ids_to_embed, new_embeddings):
#     154     id_to_embed_map[new_id].append(text_embedding)
#
# File ~/Documents/ryanpeach/llama_index/llama_index/embeddings/base.py:250, in BaseEmbedding.get_text_embedding_batch(self, texts, show_progress)
#     244 if idx == len(texts) - 1 or len(cur_batch) == self.embed_batch_size:
#     245     # flush
#     246     with self.callback_manager.event(
#     247         CBEventType.EMBEDDING,
#     248         payload={EventPayload.SERIALIZED: self.to_dict()},
#     249     ) as event:
# --> 250         embeddings = self._get_text_embeddings(cur_batch)
#     251         result_embeddings.extend(embeddings)
#     252         event.on_end(
#     253             payload={
#     254                 EventPayload.CHUNKS: cur_batch,
#     255                 EventPayload.EMBEDDINGS: embeddings,
#     256             },
#     257         )
#
# File ~/Documents/ryanpeach/llama_index/llama_index/embeddings/openai.py:340, in OpenAIEmbedding._get_text_embeddings(self, texts)
#     333 def _get_text_embeddings(self, texts: List[str]) -> List[List[float]]:
#     334     """Get text embeddings.
#     335
#     336     By default, this is a wrapper around _get_text_embedding.
#     337     Can be overridden for batch queries.
#     338
#     339     """
# --> 340     return get_embeddings(
#     341         self._client,
#     342         texts,
#     343         engine=self._text_engine,
#     344         **self.additional_kwargs,
#     345     )
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/tenacity/__init__.py:289, in BaseRetrying.wraps.<locals>.wrapped_f(*args, **kw)
#     287 @functools.wraps(f)
#     288 def wrapped_f(*args: t.Any, **kw: t.Any) -> t.Any:
# --> 289     return self(f, *args, **kw)
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/tenacity/__init__.py:379, in Retrying.__call__(self, fn, *args, **kwargs)
#     377 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     378 while True:
# --> 379     do = self.iter(retry_state=retry_state)
#     380     if isinstance(do, DoAttempt):
#     381         try:
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/tenacity/__init__.py:325, in BaseRetrying.iter(self, retry_state)
#     323     retry_exc = self.retry_error_cls(fut)
#     324     if self.reraise:
# --> 325         raise retry_exc.reraise()
#     326     raise retry_exc from fut.exception()
#     328 if self.wait:
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/tenacity/__init__.py:158, in RetryError.reraise(self)
#     156 def reraise(self) -> t.NoReturn:
#     157     if self.last_attempt.failed:
# --> 158         raise self.last_attempt.result()
#     159     raise self
#
# File ~/.pyenv/versions/3.10.12/lib/python3.10/concurrent/futures/_base.py:451, in Future.result(self, timeout)
#     449     raise CancelledError()
#     450 elif self._state == FINISHED:
# --> 451     return self.__get_result()
#     453 self._condition.wait(timeout)
#     455 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~/.pyenv/versions/3.10.12/lib/python3.10/concurrent/futures/_base.py:403, in Future.__get_result(self)
#     401 if self._exception:
#     402     try:
# --> 403         raise self._exception
#     404     finally:
#     405         # Break a reference cycle with the exception in self._exception
#     406         self = None
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/tenacity/__init__.py:382, in Retrying.__call__(self, fn, *args, **kwargs)
#     380 if isinstance(do, DoAttempt):
#     381     try:
# --> 382         result = fn(*args, **kwargs)
#     383     except BaseException:  # noqa: B902
#     384         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File ~/Documents/ryanpeach/llama_index/llama_index/embeddings/openai.py:161, in get_embeddings(client, list_of_text, engine, **kwargs)
#     157 assert len(list_of_text) <= 2048, "The batch size should not be larger than 2048."
#     159 list_of_text = [text.replace("\n", " ") for text in list_of_text]
# --> 161 data = client.embeddings.create(input=list_of_text, model=engine, **kwargs).data
#     162 return [d.embedding for d in data]
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/openai/resources/embeddings.py:105, in Embeddings.create(self, input, model, encoding_format, user, extra_headers, extra_query, extra_body, timeout)
#      99         embedding.embedding = np.frombuffer(  # type: ignore[no-untyped-call]
#     100             base64.b64decode(data), dtype="float32"
#     101         ).tolist()
#     103     return obj
# --> 105 return self._post(
#     106     "/embeddings",
#     107     body=maybe_transform(params, embedding_create_params.EmbeddingCreateParams),
#     108     options=make_request_options(
#     109         extra_headers=extra_headers,
#     110         extra_query=extra_query,
#     111         extra_body=extra_body,
#     112         timeout=timeout,
#     113         post_parser=parser,
#     114     ),
#     115     cast_to=CreateEmbeddingResponse,
#     116 )
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/openai/_base_client.py:1055, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1041 def post(
#    1042     self,
#    1043     path: str,
#    (...)
#    1050     stream_cls: type[_StreamT] | None = None,
#    1051 ) -> ResponseT | _StreamT:
#    1052     opts = FinalRequestOptions.construct(
#    1053         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1054     )
# -> 1055     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/openai/_base_client.py:834, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     825 def request(
#     826     self,
#     827     cast_to: Type[ResponseT],
#    (...)
#     832     stream_cls: type[_StreamT] | None = None,
#     833 ) -> ResponseT | _StreamT:
# --> 834     return self._request(
#     835         cast_to=cast_to,
#     836         options=options,
#     837         stream=stream,
#     838         stream_cls=stream_cls,
#     839         remaining_retries=remaining_retries,
#     840     )
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/openai/_base_client.py:890, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     888 except Exception as err:
#     889     if retries > 0:
# --> 890         return self._retry_request(
#     891             options,
#     892             cast_to,
#     893             retries,
#     894             stream=stream,
#     895             stream_cls=stream_cls,
#     896         )
#     897     raise APIConnectionError(request=request) from err
#     899 return self._process_response(
#     900     cast_to=cast_to,
#     901     options=options,
#    (...)
#     904     stream_cls=stream_cls,
#     905 )
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/openai/_base_client.py:925, in SyncAPIClient._retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#     921 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#     922 # different thread if necessary.
#     923 time.sleep(timeout)
# --> 925 return self._request(
#     926     options=options,
#     927     cast_to=cast_to,
#     928     remaining_retries=remaining,
#     929     stream=stream,
#     930     stream_cls=stream_cls,
#     931 )
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/openai/_base_client.py:890, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     888 except Exception as err:
#     889     if retries > 0:
# --> 890         return self._retry_request(
#     891             options,
#     892             cast_to,
#     893             retries,
#     894             stream=stream,
#     895             stream_cls=stream_cls,
#     896         )
#     897     raise APIConnectionError(request=request) from err
#     899 return self._process_response(
#     900     cast_to=cast_to,
#     901     options=options,
#    (...)
#     904     stream_cls=stream_cls,
#     905 )
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/openai/_base_client.py:925, in SyncAPIClient._retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#     921 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#     922 # different thread if necessary.
#     923 time.sleep(timeout)
# --> 925 return self._request(
#     926     options=options,
#     927     cast_to=cast_to,
#     928     remaining_retries=remaining,
#     929     stream=stream,
#     930     stream_cls=stream_cls,
#     931 )
#
#     [... skipping similar frames: SyncAPIClient._request at line 890 (7 times), SyncAPIClient._retry_request at line 925 (7 times)]
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/openai/_base_client.py:890, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     888 except Exception as err:
#     889     if retries > 0:
# --> 890         return self._retry_request(
#     891             options,
#     892             cast_to,
#     893             retries,
#     894             stream=stream,
#     895             stream_cls=stream_cls,
#     896         )
#     897     raise APIConnectionError(request=request) from err
#     899 return self._process_response(
#     900     cast_to=cast_to,
#     901     options=options,
#    (...)
#     904     stream_cls=stream_cls,
#     905 )
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/openai/_base_client.py:925, in SyncAPIClient._retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#     921 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#     922 # different thread if necessary.
#     923 time.sleep(timeout)
# --> 925 return self._request(
#     926     options=options,
#     927     cast_to=cast_to,
#     928     remaining_retries=remaining,
#     929     stream=stream,
#     930     stream_cls=stream_cls,
#     931 )
#
# File ~/.pyenv/versions/3.10.12/envs/llama_index3/lib/python3.10/site-packages/openai/_base_client.py:897, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     889     if retries > 0:
#     890         return self._retry_request(
#     891             options,
#     892             cast_to,
#    (...)
#     895             stream_cls=stream_cls,
#     896         )
# --> 897     raise APIConnectionError(request=request) from err
#     899 return self._process_response(
#     900     cast_to=cast_to,
#     901     options=options,
#    (...)
#     904     stream_cls=stream_cls,
#     905 )
#
# APIConnectionError: Connection error.

# %%
pprint(retriever.retrieve(uuid_from_text)[0].node.get_content())

# %%
pprint(
    [
        n.node.get_content()
        for n in retriever.retrieve("SentenceWindowNodeParser")
    ]
)

# %% [markdown]
# # Future Improvements
#
# * An example of using a VectorStore for fuzzy finding.
# * Adding uuids to the end and beginning of code parsed text so its easier to know what to search for in-order.
# * More languages
#
# Feel free to contribute!
